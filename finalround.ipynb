# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
turkish_stopwords = stopwords.words('turkish')
english_stopwords = stopwords.words('english')
combined_stopwords = list(set(turkish_stopwords + english_stopwords))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ganga\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
train_classification = pd.read_csv('train-classification.csv')
train_classification = train_classification.rename(columns={'Unnamed: 0': 'username', 'label': 'label'})

train_classification["label"] = train_classification['label'].apply(str.lower)
username_category = train_classification.set_index('username').to_dict()['label']

# Load the new CSV file
annotated_users = pd.read_csv('annotated_users_CS412-5189b0cc4cb9.csv')

for index, row in annotated_users.iterrows():
    if index == 0:  # If it is the first row, skip
        continue
    username = row['username']
    if pd.isnull(row['influencerCategory']):
        continue
    influencer_category = row['influencerCategory'].strip().lower()  # Normalize (remove spaces and convert to lowercase)
    if username not in username_category:
        username_category[username] = influencer_category

# Apply the same process when adding the other file
annotated_users = pd.read_csv('annotated_users_CS412-0e2ff92120f3.csv')
for index, row in annotated_users.iterrows():
    if index == 0:  # If it is the first row, skip
        continue
    username = row['username']
    if pd.isnull(row['influencerCategory']):
        continue
    influencer_category = row['influencerCategory'].strip().lower()  # Normalize
    if username not in username_category:
        username_category[username] = influencer_category

# Additionally, normalize all existing categories
username_category = {k: v.strip().lower() for k, v in username_category.items()}

# %%
normalized_table = {
    'mom and children' : "Mom and Children",
    "food" : "Food",
    'travel' : "Travel",
    'fashion' : "Fashion",
    'gaming' : "Gaming",
    'health and lifestyle' : "Health and Lifestyle",
    'entertainment' : "Entertainment",
    'tech': "Tech",
    'sports' : "Sports",
    'art' : "Art"
}
normalized_table
# Out:
# {'mom and children': 'Mom and Children',
#  'food': 'Food',
#  'travel': 'Travel',
#  'fashion': 'Fashion',
#  'gaming': 'Gaming',
#  'health and lifestyle': 'Health and Lifestyle',
#  'entertainment': 'Entertainment',
#  'tech': 'Tech',
#  'sports': 'Sports',
#  'art': 'Art'}

# %%
annotated_users = pd.read_csv('annotated_users_CS412-5189b0cc4cb9.csv')
annotated_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   username            150 non-null    object
#  1   url                 150 non-null    object
#  2   influencerCategory  147 non-null    object
#  3   influencerMention   147 non-null    object
#  4   accountType         147 non-null    object
# dtypes: object(5)
# memory usage: 6.0+ KB

# %%
username_category
# Out:
# {'taskirancemal': 'mom and children',
#  'tam_kararinda': 'food',
#  'spart4nn': 'food',
#  'sosyalyiyiciler': 'food',
#  'sonaydizdarahad': 'mom and children',
#  'somersivrioglu': 'food',
#  'sinankoc': 'travel',
#  'simulasyonturk': 'gaming',
#  'savas_karakas_sudaki_izler': 'travel',
#  'sakinenurunannesi': 'mom and children',
#  'ruyabuyuktetik': 'fashion',
#  'raykakumru': 'health and lifestyle',
#  'pintipanda': 'gaming',
#  'pinarindepresyonu': 'health and lifestyle',
#  'pinarhotic': 'health and lifestyle',
#  'pinardonmez_': 'mom and children',
#  'ozgeninoltasi': 'food',
#  'nayaozgun': 'fashion',
#  'nataliyarcan': 'health and lifestyle',
#  'muthispsikoloji': 'health and lifestyle',
#  'murattekecicom': 'tech',
#  'mrsisbeceren': 'mom and children',
#  'mosyosokola': 'food',
#  'mirandaorlayn': 'entertainment',
#  'mezarci_pubg': 'gaming',
#  'mervedemireltaskiran': 'travel',
#  'lifewithapineapple': 'travel',
#  'lalsefkatli': 'travel',
#  'kutupanne': 'mom and children',
#  'kosifcihan': 'health and lifestyle',
#  'kisikatescom': 'food',
#  'kaankural2': 'sports',
#  'ilgeipek': 'tech',
#  'ilaydasurucuu': 'fashion',
#  'ifkoparan': 'travel',
#  'hurkangugen': 'art',
#  'htcebrar': 'mom and children',
#  'hominigirtlakgurme': 'food',
#  'hergun1yenibilgi': 'health and lifestyle',
#  'happycoffeehours': 'travel',
#  'gurmediyet': 'food',
#  'girisimci_muhendis': 'tech',
#  'gezerbros': 'travel',
#  'firatsobutay': 'entertainment',
#  'ezgikamadan': 'fashion',
#  'endermutfakta': 'food',
#  'draycakaya': 'health and lifestyle',
#  'dogankabak': 'tech',
#  'dilrubasaricimen': 'fashion',
#  'dilarakurtulms': 'fashion',
#  'didemmaden': 'mom and children',
#  'didem.zeybek': 'health and lifestyle',
#  'dekorz_blog': 'food',
#  'damlaaltun': 'fashion',
#  'cemresilatilgan': 'fashion',
#  'cakirtulin': 'mom and children',
#  'bodyographer': 'health and lifestyle',
#  'birselvardarlidemirmen': 'sports',
#  'biraltmislik': 'travel',
#  'bilmemenayip': 'entertainment',
#  'bilime.dair': 'tech',
#  'balooun': 'fashion',
#  'atmacavolkan7': 'health and lifestyle',
#  'atalaraleyna': 'fashion',
#  'atakantarkann': 'sports',
#  'askinmenusu': 'food',
#  'arabaciadamlar': 'tech',
#  'anlatanadamlar': 'entertainment',
#  'adanadacocukolmak': 'mom and children',
#  'ozcivelekseyahat': 'travel',
#  'theurbangoat.ist': 'food',
#  'inancbaharat': 'food',
#  'pidebansariyer': 'food',
#  'mhpkadirbiyik26': 'health and lifestyle',
#  'merkezefendibelediye': 'mom and children',
#  'rodostokuyumculuk': 'fashion',
#  'cinematicaistanbul': 'entertainment',
#  'rakunmobilite': 'tech',
#  'bitexen': 'sports',
#  'zeynep': 'mom and children',
#  'hisarhospital': 'health and lifestyle',
#  'sendanismanlik': 'travel',
#  'hangoutbahce': 'entertainment',
#  'yalcinyasemin': 'entertainment',
#  'quyumcujewellery': 'fashion',
#  'mrkumpir': 'food',
#  'dmrsupermarketleri': 'food',
#  'selimiyemuhallebicisi': 'food',
#  'bakuslunalounge': 'entertainment',
#  'cankiriapartavsa': 'travel',
#  'kiralarsin': 'tech',
#  'latanyaparkresort': 'travel',
#  'kilifgezegenn': 'fashion',
#  'naturesbounty_tr': 'health and lifestyle',
#  'indirimkodu': 'tech',
#  'prof.dr.mustafaozturk': 'health and lifestyle',
#  'umitkaran': 'sports',
#  'myivsolutions': 'health and lifestyle',
#  'baskentkulturyolu': 'entertainment',
#  'sibelkavaklioglu': 'fashion',
#  'kanvastik': 'art',
#  'middelrestaurant': 'food',
#  'kolburanos': 'food',
#  'polsgurme': 'food',
#  'yaprakbarantecir': 'health and lifestyle',
#  'erciyeskykmrkz': 'travel',
#  'selvagida': 'food',
#  'jwmarriottistanbulbosphorus': 'travel',
#  'desk360com': 'tech',
#  'bcistcenter': 'tech',
#  'roboengineering': 'tech',
#  'charidesseafood': 'food',
#  'taksim360': 'travel',
#  'degirmencifirini': 'food',
#  'nisantasibaskose.tr': 'food',
#  'hechaturkiye': 'food',
#  'mekaglobal': 'tech',
#  'maccafish': 'food',
#  'nakoiplikleri': 'fashion',
#  'pendikyuzyilhastanesi': 'health and lifestyle',
#  'bgst_tiyatro': 'art',
#  'ttiizmir': 'travel',
#  'palomaperissia': 'travel',
#  'transformersturkiye': 'entertainment',
#  'metin.mamati': 'travel',
#  'bilinyazilim': 'tech',
#  'risendanismanlik': 'tech',
#  'gurmarmarket': 'food',
#  'lezzetsteakhouse': 'food',
#  'piraye.organic': 'food',
#  'arastirananneler': 'mom and children',
#  'indexgrup': 'tech',
#  'armaganoyuncak': 'mom and children',
#  'kitchenlab_alsancak': 'food',
#  'dsdamatonline': 'fashion',
#  'kitestravel': 'travel',
#  'kahvecenterr': 'food',
#  'efesselcukbel': 'mom and children',
#  'orta_anadolu': 'fashion',
#  'memorial_sisli_tupbebek': 'health and lifestyle',
#  'sapancabld': 'art',
#  'dijitalekosistem': 'tech',
#  'frinkcoffee': 'food',
#  'tsabodrum': 'art',
#  'hatyapim': 'entertainment',
#  'arconkozmetik': 'fashion',
#  'cpmyazilim': 'tech',
#  'narmanbelediyesi': 'mom and children',
#  'ltbjeans': 'fashion',
#  'kitesgroup': 'travel',
#  'diyanetch': 'health and lifestyle',
#  'hacidayi.duzce': 'food',
#  'tuttur': 'sports',
#  'sanatabiyer': 'art',
#  'enoliaofficial': 'fashion',
#  'medicasimple': 'tech',
#  'atom_dunyasi_alanya': 'food',
#  'eticrax': 'entertainment',
#  'murverkarakoy': 'food',
#  'msigaming_turkey': 'tech',
#  'sabunperisi': 'fashion',
#  'pilotturkiye': 'art',
#  'erahaviationacademy': 'travel',
#  'etikimza': 'tech',
#  'cekmekoymaximal': 'health and lifestyle',
#  'lifeatciceksepeti': 'entertainment',
#  'asansor.market': 'tech',
#  'daddymedya': 'tech',
#  'savronik': 'tech',
#  '_soktas_': 'fashion',
#  'becerencafe': 'travel',
#  'excalibur.casper': 'tech',
#  'hotelforex': 'travel',
#  'dikkatcocuk': 'mom and children',
#  'uludaginfo': 'travel',
#  'etigong': 'food',
#  'perdecimustafa': 'fashion',
#  'kensushiandmore': 'food',
#  'scaniatr': 'tech',
#  'erdil': 'art',
#  'radissoncollectionbodrum': 'travel',
#  'pembekurdeletr': 'health and lifestyle',
#  'midpointbistrocafe': 'food',
#  'saglikbakanligi': 'health and lifestyle',
#  'baklavacigulluoglu': 'food',
#  'alpemfiltrehidrolik': 'tech',
#  'aymanmarket_07': 'food',
#  'ercankardeslerkuyumculuk': 'fashion',
#  'zaferinyerirestaurant': 'food',
#  'o2fatsa': 'sports',
#  'boschprofessionalturkiye': 'tech',
#  'rota.restaurant': 'food',
#  'oykulojistik': 'mom and children',
#  'bublockchaintechclub': 'tech',
#  'babylifekordonkani': 'health and lifestyle',
#  'eskocake': 'food',
#  'kalecikbeyazsaraygazinosu': 'entertainment',
#  'yalicapkiniresmi': 'entertainment',
#  'aksayyangin1': 'tech',
#  'yemmakofficial': 'tech',
#  'alimyapim': 'entertainment',
#  'hareketozgurluktur': 'health and lifestyle',
#  'cotanak_off_road': 'travel',
#  'akademibinicilik': 'sports',
#  'sporplatformu': 'sports',
#  'eczalv': 'health and lifestyle',
#  'serasayar': 'sports',
#  'akademisyenanne': 'mom and children',
#  'veyselzaloglu': 'entertainment',
#  'varunagezgin': 'travel',
#  'impluto.ip': 'entertainment',
#  'halillkaptan': 'travel',
#  'tekbasinadaolur': 'travel',
#  'base__a': 'fashion',
#  'canyucetas': 'entertainment',
#  'meryemgunnduz': 'fashion',
#  'the.llc': 'entertainment',
#  'hnourk': 'travel',
#  'yargictony': 'gaming',
#  'fatmanuurkaraman': 'mom and children',
#  'canaycolakoglu': 'food',
#  'unlostv': 'gaming',
#  'bihterkocc': 'fashion',
#  'sabahspor': 'sports',
#  'yasamfoods': 'food',
#  'bytezzhome': 'fashion',
#  'efelerciftligi': 'food',
#  'nobbyrestaurant_lounge': 'food',
#  'messtkuneffe': 'food',
#  'nemigiymeli': 'fashion',
#  'bodrumantiktiyatro': 'entertainment',
#  'eyupmodesa': 'fashion',
#  'oguzhankoctv': 'entertainment',
#  'inanturizm': 'travel',
#  'ulkerkrispi': 'food',
#  'kirazbeachotel': 'travel',
#  'unyedh': 'health and lifestyle',
#  'turkishairlinesholidays': 'travel',
#  'proto_yazilim': 'tech',
#  'baybilinmeyen': 'art',
#  'wellcaretr': 'health and lifestyle',
#  'gulluoglu': 'food',
#  'off_gumusluk': 'food',
#  'dentramdisklinigi': 'health and lifestyle',
#  'hazarerguclu': 'fashion',
#  'tanerisbir': 'entertainment',
#  'peypagurmejet': 'food',
#  'vdvolkandogan': 'mom and children',
#  'emineerdogan': 'mom and children',
#  'cookplus': 'food',
#  'tonyhawk': 'sports',
#  'serifoglucafe': 'food',
#  'lussomobilya': 'art',
#  'floryalirestoran': 'food',
#  'parlarfidan35': 'food',
#  'kokopatik': 'mom and children',
#  'pangu_karakoy': 'fashion',
#  'tuzlagonulelleri': 'mom and children',
#  'desimerkez': 'tech',
#  'hanifpehlivanoglu': 'food',
#  'alestaguvenlikordu': 'tech',
#  'beyceribal': 'food',
#  'igneeoyacii': 'fashion',
#  '7mehmetrestaurant': 'food',
#  'netsvadi': 'health and lifestyle',
#  'bilkom': 'tech',
#  'izmir_beydag_tim': 'health and lifestyle',
#  'ticmglobal': 'tech',
#  'aretkamar': 'mom and children',
#  'arda.tulum_': 'art',
#  'billsfooddrink': 'food',
#  'sehagenclik': 'mom and children',
#  'cediosman': 'sports',
#  'altincizgi': 'fashion',
#  'meridolturkiye': 'health and lifestyle',
#  'tatilturizm': 'travel',
#  'cupofjoy_istanbul': 'food',
#  'ozakgokturk': 'travel',
#  'jetract': 'tech',
#  'caliskanbt': 'tech',
#  'miamassimocafe': 'food',
#  'hacettepeblockchain': 'tech',
#  'turhost': 'tech',
#  'altkatsanat': 'art',
#  'teksanturkiye': 'tech',
#  'canrtopcu': 'fashion',
#  'honorturkiye': 'tech',
#  'bahcekadikoyrestaurant': 'food',
#  'batubozkan': 'gaming',
#  'dresortayvalik': 'travel',
#  'philipsaventtr': 'mom and children',
#  'indes.inc': 'tech',
#  'nicepro.world': 'tech',
#  'evrekaco': 'tech',
#  'cembolukbasi': 'sports',
#  'photohadrian': 'travel',
#  'tezgahsokaklezzetleri': 'food',
#  'levanteculina': 'food',
#  'kedisahne': 'entertainment',
#  'tatilevimkusadasi': 'travel',
#  'gungorenhastanesi': 'health and lifestyle',
#  'bakiersoymhp': 'sports',
#  'segway_turkiye': 'travel',
#  'akademi_hastanesi': 'health and lifestyle',
#  'dikkatbebekcikabilir': 'mom and children',
#  'kitespots.turkey': 'travel',
#  'kravatistan': 'fashion',
#  'storetada': 'food',
#  'deichmann_tr': 'fashion',
#  'kusadasiavm': 'health and lifestyle',
#  'antalyagezirehberi': 'travel',
#  'esmaceyizz': 'fashion',
#  'profdrferhanoz': 'health and lifestyle',
#  'mervebolugur': 'entertainment',
#  'transfermarkt.com.tr': 'sports',
#  'alsancakturizmofficial': 'travel',
#  'obamakarna': 'food',
#  'asiyan.restaurant': 'food',
#  'pharmatontr': 'health and lifestyle',
#  'acerturkey': 'tech',
#  'aris_pirlanta': 'fashion',
#  'bursasporluyuz': 'sports',
#  'lenovoturkiye': 'tech',
#  'azoncekonustum': 'entertainment',
#  'muratercan0606': 'mom and children',
#  'diyetisyenhusniyeodabas': 'health and lifestyle',
#  'trendyaspendosbeach': 'travel',
#  'geyikkadikoy': 'food',
#  'tacstyle': 'fashion',
#  'testpark.llc': 'tech',
#  'hatemoglu1924': 'fashion',
#  'levantine_cakes': 'food',
#  'gezsenbatman': 'food',
#  'annenin.icsesi': 'mom and children',
#  'peynircibaba': 'food',
#  'brandverseawards': 'entertainment',
#  'gsb_van': 'sports',
#  'bodrumlupastalar': 'food',
#  'olymposteleferik2365m': 'travel',
#  'bodrumeskikoy': 'food',
#  'turkishtechnic': 'tech',
#  'incehesap': 'tech',
#  'egbilisim': 'tech',
#  'yalikavakmarina': 'travel',
#  'atlaskaravan': 'travel',
#  'cafemiz_ankara': 'food',
#  'kuslemecimehmetusta': 'food',
#  'mamigurme': 'food',
#  'seturselect': 'travel',
#  'cityfarm': 'food',
#  'pluscreativeajans': 'tech',
#  'cemmumcu': 'art',
#  'senyonet': 'tech',
#  'engellicocukhaklariagi': 'mom and children',
#  'papermoontr': 'food',
#  'utkucoskun__': 'fashion',
#  'asumankrauseofficial': 'fashion',
#  'dogaciyizgourmet': 'food',
#  'pembeteknoloji': 'tech',
#  'gymnasiumedremit': 'health and lifestyle',
#  'drmelekvuslatozdogan': 'health and lifestyle',
#  'trtdiyanetcocuk': 'mom and children',
#  'bealjewelry': 'fashion',
#  'bilkentsymphony': 'entertainment',
#  'sarihanistinye_': 'food',
#  'milas_belediyesi': 'mom and children',
#  'asladurma': 'sports',
#  'ramadaerzurum': 'travel',
#  'sena.sener': 'fashion',
#  'sarpablo11': 'travel',
#  'ganioglu_beko': 'tech',
#  'northpiers.konakpier': 'food',
#  'imutorturkiye': 'health and lifestyle',
#  'tunashelvarecel': 'food',
#  'chillaxtr': 'food',
#  'ecemtturann': 'fashion',
#  'solidict': 'tech',
#  'yenasoftyazilim': 'tech',
#  'tatlidunyasidergisi': 'food',
#  'bonetdoner': 'food',
#  'gymboreekayseri': 'mom and children',
#  'yerindengelsin.com.tr': 'food',
#  'istanbulsafakhastanesi': 'health and lifestyle',
#  'loyacomtr': 'fashion',
#  'hasibeeren': 'entertainment',
#  'fakirevaletleri': 'tech',
#  'ecrownish': 'fashion',
#  'alcatelmobiletr': 'tech',
#  'sysmondyazilim': 'tech',
#  'lilyjcollins': 'fashion',
#  'atvmilyoner': 'entertainment',
#  'alisofuoglu_': 'sports',
#  'genclerbirligisk': 'sports',
#  'ozpack': 'fashion',
#  'babyteenmugla': 'fashion',
#  'antalyacityzone': 'travel',
#  'agaoglumymountain': 'travel',
#  'tarikcetin1': 'sports',
#  'fbespor': 'gaming',
#  'dergipdr': 'health and lifestyle',
#  'craftmakina': 'tech',
#  'op.dr.isakaman': 'health and lifestyle',
#  'gokhaninler': 'sports',
#  'prilturkiye': 'health and lifestyle',
#  'storkcamper': 'travel',
#  'meldaarat': 'entertainment',
#  'ulkeenerji': 'tech',
#  'sprite_tr': 'entertainment',
#  'bilgiblockchain': 'tech',
#  'derimdermatoloji': 'health and lifestyle',
#  'zoomlion.platform.turkiye': 'tech',
#  'beforesunsetbeach': 'travel',
#  'historyhaireurope': 'health and lifestyle',
#  'bataryasan': 'tech',
#  'orzaxturkiye': 'health and lifestyle',
#  'playspor': 'sports',
#  'risoturkiye': 'tech',
#  'plus.restaurant': 'food',
#  'verandaalacati': 'food',
#  'etilifalif': 'food',
#  'dujabodrum': 'travel',
#  'unuvarsuadiye': 'food',
#  'tribundergi': 'sports',
#  'kayropraktik': 'health and lifestyle',
#  'haciolabi.tr': 'food',
#  'oferxl': 'fashion',
#  'lassatyres': 'travel',
#  'dodotakitasarim': 'fashion',
#  'artemistasmahzen': 'food',
#  'esarj': 'tech',
#  'ido': 'travel',
#  'hdisigortaspor': 'sports',
#  'gorillasapp.uk': 'food',
#  'zeyland.official': 'fashion',
#  'kalpcidoktor': 'health and lifestyle',
#  'zenpirlanta': 'fashion',
#  'istanbulakvaryum': 'travel',
#  'biokimtekniksistemler': 'tech',
#  'venioagency': 'tech',
#  'hatayguru': 'food',
#  'havelsan_resmi': 'tech',
#  'sezgin_kalayci': 'sports',
#  'teaminspark': 'tech',
#  'orientturkiye': 'fashion',
#  'reiskuyumculuk': 'fashion',
#  'burak_elmas': 'sports',
#  'zorluenergysolutions': 'tech',
#  'cigdemtunctiyatrosu': 'entertainment',
#  'toprakseker': 'fashion',
#  'nilkaraibrahimgil': 'entertainment',
#  'ituariteknokent': 'tech',
#  'korlasmarin': 'travel',
#  'pozantibelediyesi01': 'entertainment',
#  'studiohouse.tr': 'food',
#  'siserisitmemerkezi': 'health and lifestyle',
#  'tirkamyonresimleri': 'travel',
#  'palomaforestaresort': 'travel',
#  'akdemir_makina': 'tech',
#  'bialetti_turkiye': 'food',
#  'kenansofuoglu': 'sports',
#  'uyuyan.bebekler': 'mom and children',
#  'sisadtr': 'health and lifestyle',
#  'himalaya_yarns': 'art',
#  'suletrem': 'mom and children',
#  'esrefapak': 'sports',
#  'emrenesliphotography': 'art',
#  'docdrozlemsilistreli': 'health and lifestyle',
#  'alacatimuhallebicisi': 'food',
#  'lalapasabelediyesi': 'travel',
#  'webtekno': 'tech',
#  'bonnatr': 'food',
#  'gezsentrakya': 'travel',
#  'yurtkonserve': 'food',
#  'hakanyasar': 'fashion',
#  '1milyonktp': 'mom and children',
#  'neocreativeofficial': 'tech',
#  'flasunlumamulleri': 'food',
#  'brc_turkiye': 'tech',
#  'vakkoesmodistanbul': 'fashion',
#  'idealsarraf': 'fashion',
#  'gsb_sirnak': 'sports',
#  'muslera': 'sports',
#  'mimakieurasia': 'tech',
#  'bettyandsamm': 'fashion',
#  'savra_bodrum': 'travel',
#  'drfaki': 'health and lifestyle',
#  'sile_bld': 'mom and children',
#  'orhanelibel': 'mom and children',
#  'semtberberi': 'fashion',
#  'novasure.turkiye': 'health and lifestyle',
#  'canonturkiye': 'tech',
#  'kahverengicafe': 'food',
#  'oztikitchen': 'food',
#  'boostcamplive': 'sports',
#  'eraysahinsev_dis_poliklinigi': 'health and lifestyle',
#  'hasgarantiroasters': 'food',
#  '2daydance': 'entertainment',
#  'gokhantore': 'sports',
#  'gurmexcom': 'food',
#  'sagliktagenc': 'health and lifestyle',
#  'mendelscomtr': 'food',
#  'clubdizalya': 'travel',
#  'kalafatlarmarket': 'food',
#  'turkiyemsdernegi': 'health and lifestyle',
#  'nouva_art': 'art',
#  'liefurla': 'food',
#  'neylemeylemeyhane': 'food',
#  'goznurugross': 'food',
#  'zahideyetis': 'mom and children',
#  'cafe.460': 'food',
#  'istcaf': 'art',
#  'adilesultanevyemekleri': 'food',
#  'superoxcom': 'health and lifestyle',
#  'falcaoyusuf': 'food',
#  'ekinsarigul': 'fashion',
#  'calypsobalik': 'food',
#  'ihealthsaglik': 'health and lifestyle',
#  'kayturkayseri': 'food',
#  'empaelectronics': 'tech',
#  'apex.dentalclinic': 'health and lifestyle',
#  'arkascesmesitespor': 'sports',
#  'senseshotelbodrum': 'travel',
#  'donercialisan': 'food',
#  'kirmizisemsiyedernegi': 'health and lifestyle',
#  'downtownfoodclub': 'food',
#  'gununbereketitv': 'mom and children',
#  'faststepshoes': 'fashion',
#  'balamakina': 'tech',
#  'tatiljetitr': 'travel',
#  'suflorkadikoy': 'food',
#  'gokhan_alkan': 'travel',
#  'canakkalemobilmuzesi': 'travel',
#  'businessfundays': 'food',
#  'mr.baoistanbul': 'food',
#  'projx.digital': 'tech',
#  'murseldanisman': 'fashion',
#  'apinoxindustrialkitchen': 'food',
#  'sebzetarifi': 'food',
#  'yesilkundura': 'fashion',
#  'bizimmutfak': 'food',
#  'burakkbulut23': 'entertainment',
#  'pointgorsel': 'entertainment',
#  'cafe_pupa': 'entertainment',
#  'aydintrkmn': 'sports',
#  'enterogerminatr': 'health and lifestyle',
#  'boyalikbeachhotelspacesme': 'travel',
#  'yemeksepeti': 'food',
#  'cankiriotelavsa': 'travel',
#  'sazakimeyhane': 'food',
#  'herseyasktanbebek': 'fashion',
#  'otisturkiye': 'tech',
#  'eklerciumit': 'food',
#  'sherwoodexclusive_kemer': 'travel',
#  'kartalotelbolu': 'travel',
#  'livanekadikoy': 'entertainment',
#  'revoday': 'health and lifestyle',
#  'erdemlersogutma': 'food',
#  'royaofficial': 'fashion',
#  '46oyunculari': 'entertainment',
#  'emreyzcoglu': 'art',
#  'bilgiguvende': 'tech',
#  'altinbasjewelry': 'fashion',
#  'yoncalodge': 'travel',
#  'siyahbeyazankara': 'art',
#  'palmeramobilya': 'mom and children',
#  'bizimtoptan': 'food',
#  'bausta.suadiye': 'food',
#  'dhlexpressturkiye': 'sports',
#  'vitaminye': 'food',
#  'unolezzetleri': 'food',
#  'ciborekci': 'food',
#  'adim_adim': 'sports',
#  'stratejikseo': 'tech',
#  'laluztour': 'travel',
#  'bugusto': 'food',
#  'newmoodmobilya': 'fashion',
#  'bilimvteknoloji': 'tech',
#  'clandestino_istanbul': 'fashion',
#  'pirayekafekadikoy': 'food',
#  'tanegurme': 'food',
#  'iletimerkezi': 'tech',
#  'tanferhealth': 'health and lifestyle',
#  'bob.gym': 'sports',
#  'pronetguvenlik': 'tech',
#  'bizimozgen': 'health and lifestyle',
#  'sunakepoluataman': 'entertainment',
#  'goldverikurtarma': 'tech',
#  'dukkannistanbul': 'food',
#  'drsepit': 'health and lifestyle',
#  'birgelecekorg': 'mom and children',
#  'travelingokbel': 'travel',
#  'penguentepe': 'travel',
#  'reborntrainingclub': 'sports',
#  'corvoscombat': 'sports',
#  'antikrestoran': 'food',
#  'intergoz_official': 'fashion',
#  'oleafamilya': 'food',
#  'carpisanturk.camper': 'travel',
#  'murat.yildiz.cxo': 'tech',
#  'gelecekturizmde': 'travel',
#  'derincebelediyesigshm': 'mom and children',
#  'belcontiresort': 'travel',
#  'frankieistanbul': 'food',
#  'tatlisesmeram': 'food',
#  'alamexelevator': 'tech',
#  'isabetkuyumculuk': 'fashion',
#  'bursaspor': 'sports',
#  'turkiyenincayi': 'food',
#  'selinuzdl': 'travel',
#  'pakmaya': 'food',
#  'divan_bodrum': 'travel',
#  'pinebebekbezi': 'mom and children',
#  'hopdaddyburger': 'food',
#  'neslisahduzyatan': 'mom and children',
#  'acpyapielemanlari': 'tech',
#  'tckemalpasabelediyesi': 'travel',
#  'sultanas_istanbul': 'entertainment',
#  'pinarrdenizzz': 'fashion',
#  'applegurgencler': 'tech',
#  'esidaotel': 'travel',
#  'soldoutevent': 'entertainment',
#  'tavukaskina': 'food',
#  'aralik.istanbul': 'food',
#  'cumba_sahne': 'entertainment',
#  'odda75_': 'fashion',
#  'kuhneturkiye': 'food',
#  'oddgastropub': 'food',
#  'askmoyra_en': 'entertainment',
#  'direncnet': 'tech',
#  'fitstationofficial': 'health and lifestyle',
#  'avxcomtr': 'tech',
#  'maretdunyasi': 'food',
#  'senoritachocolate': 'food',
#  'adenyahotelstr': 'travel',
#  'cananerguder1': 'mom and children',
#  'fitbas': 'fashion',
#  'burger_stall': 'food',
#  'selgebeachofficial': 'travel',
#  'sosyalzoom': 'tech',
#  'bupilicentegre': 'food',
#  'alaturkishrestaurantdxb': 'food',
#  'chakrakuafor': 'fashion',
#  'pamukcuosgbbalikesir': 'health and lifestyle',
#  'hairmedico': 'health and lifestyle',
#  'aytaclezzetleri': 'food',
#  'esitadimlar': 'mom and children',
#  'antalyalist': 'travel',
#  'thepielroja': 'food',
#  'baykus_kadikoy': 'food',
#  'vclub_tr': 'travel',
#  'ulkercokokrem': 'food',
#  'christinekorda': 'food',
#  'sailingocagiz': 'travel',
#  'bilge.trn': 'mom and children',
#  'fizematipmerkezi': 'health and lifestyle',
#  'martinclubizmir': 'entertainment',
#  'mitte_karakoy': 'fashion',
#  'roketsan': 'tech',
#  'idealdentalclinic': 'health and lifestyle',
#  'kasapienchef': 'food',
#  'dentroam': 'health and lifestyle',
#  'sidestarelegance': 'travel',
#  'aslihandoganturan': 'mom and children',
#  'cafe380': 'food',
#  'magnetimarellitr': 'tech',
#  'nesquik_turkiye': 'food',
#  'coreexperiencetour': 'sports',
#  'lagioiatr': 'food',
#  'italbasket': 'sports',
#  'keskinoglu_as': 'food',
#  'niloyatv': 'mom and children',
#  'cinkopastpastil': 'health and lifestyle',
#  'marmarisadakoymarina': 'entertainment',
#  'waterbabiestr': 'mom and children',
#  'tkaracamobilya': 'fashion',
#  'gungoretlokantasi': 'food',
#  'sezaileventoglu': 'health and lifestyle',
#  'literarestaurant': 'food',
#  'cocukren': 'entertainment',
#  'outdoorfestturkiye': 'mom and children',
#  'prof.dr.ulun.ulug': 'health and lifestyle',
#  'bvuhastanesi': 'health and lifestyle',
#  'belediyesikose': 'travel',
#  'topraktanpatisserie': 'food',
#  'engincan_ec': 'art',
#  'milesandsmiles': 'travel',
#  'erdalemlaktekirdag': 'travel',
#  'nauticalhotel': 'travel',
#  'anadoluefessk': 'sports',
#  'cinaraltibeylikduzu': 'food',
#  'cukurovablockchain': 'tech',
#  'orenciftligi': 'food',
#  'twfgovtr': 'sports',
#  'pidipidiofficial': 'fashion',
#  'turkiyesualtisporlari': 'sports',
#  'sooptr': 'mom and children',
#  'btaworld': 'food',
#  'bysymakturk': 'fashion',
#  'meyhane_sisim': 'food',
#  'libertyhotelslykia': 'travel',
#  'zeytinkavlak': 'food',
#  'voguehotelbodrum': 'travel',
#  'jalo_tr': 'art',
#  'tat_ailesi': 'food',
#  'dragutsailing': 'travel',
#  'doc.dr.oktay.kaymak': 'mom and children',
#  'imamoglu_int': 'travel',
#  'thegracebrands': 'fashion',
#  'commun.store': 'fashion',
#  'secondfreshfood': 'food',
#  'amc_cookware': 'food',
#  'cekmekoybelediyesi': 'mom and children',
#  'fisiodemizmir': 'health and lifestyle',
#  'hisarkahve1928': 'food',
#  'varilcorba': 'food',
#  'gingerbreadby3': 'fashion',
#  'theasailing': 'travel',
#  'iraykuyumcu': 'fashion',
#  'escape.adventures': 'travel',
#  'swissotelresortbodrumbeach': 'travel',
#  'kidzaniaistanbul': 'mom and children',
#  'kokorastore': 'fashion',
#  'ankateknikplastik': 'tech',
#  'devawines': 'food',
#  'chantierfilms': 'entertainment',
#  'pancokids': 'fashion',
#  'hakikatkirtasiyecom': 'art',
#  'babaganusalsancak': 'entertainment',
#  'turkeysms': 'tech',
#  'mutluisiksu': 'mom and children',
#  'networkonline': 'fashion',
#  'arttechguvenlik': 'tech',
#  'seljel': 'food',
#  'holimax': 'travel',
#  'uniq2go': 'sports',
#  'op.dr.mehmetkoc': 'mom and children',
#  'levis_tr': 'fashion',
#  'tahtakalehobi': 'art',
#  '_bookreen': 'tech',
#  'smartofficetr': 'tech',
#  'hayvoree': 'food',
#  'mcdonaldsturkiye': 'food',
#  'senelfoto': 'art',
#  'voltelektrikmotorlari': 'tech',
#  'mdolcechocolate': 'food',
#  'mamabuscatering': 'food',
#  'feminis.turkiye': 'health and lifestyle',
#  'kardeseliorg': 'mom and children',
#  'artonomiagency': 'art',
#  'vitadostum': 'food',
#  'chopchopturkiye': 'food',
#  'basselpilates': 'health and lifestyle',
#  'yekbu': 'health and lifestyle',
#  'monologlarmuzesi': 'art',
#  'dizalyapalmgarden': 'travel',
#  'artdreamix': 'art',
#  'monteida': 'food',
#  'clinic_atasehir': 'health and lifestyle',
#  'hatkosports': 'sports',
#  'akdeniztoros': 'food',
#  'sercevdernegi': 'mom and children',
#  'sinemozler': 'food',
#  'kytechngaming': 'tech',
#  'jungheinrichturkiye': 'tech',
#  'birecikikincibahar': 'food',
#  'turkiyehastanesi': 'health and lifestyle',
#  'maltana_turkiye': 'food',
#  'mersinnarenciyefestivali': 'food',
#  'dermazoneorg': 'health and lifestyle',
#  'ekmobcom': 'tech',
#  'diyetisyencereniseri': 'health and lifestyle',
#  'golfdondurmalar': 'food',
#  'go.kars': 'travel',
#  'citirwaffle': 'food',
#  'eczazone': 'health and lifestyle',
#  'gurmecanlar': 'food',
#  'celalkose66': 'mom and children',
#  'haarunaksu': 'food',
#  'heijann': 'entertainment',
#  'ayhantarakci': 'tech',
#  'makibahce': 'food',
#  'nevrabilemm': 'mom and children',
#  'delicatessenist': 'food',
#  'mudanyayagel': 'travel',
#  'semersah.turizm': 'travel',
#  'caligo.technology': 'tech',
#  'blue_fitness_club': 'health and lifestyle',
#  'izmirgeziyorr': 'travel',
#  'nenibrasserie': 'food',
#  'rumelicafebistro99': 'food',
#  'istanbulairshow': 'travel',
#  'maksutaskar': 'food',
#  'planet2see': 'travel',
#  'markasyadis': 'health and lifestyle',
#  'barisatay': 'art',
#  'leyladansonra': 'mom and children',
#  'duja_hotels': 'travel',
#  'tiyatro.in': 'entertainment',
#  'cinnagenilac': 'tech',
#  'swissoffices': 'tech',
#  'busrapekin': 'fashion',
#  'wtcn': 'gaming',
#  'easycep': 'tech',
#  'azbariatrics_resmi': 'health and lifestyle',
#  'esqtekstil': 'fashion',
#  'tartimedikal': 'health and lifestyle',
#  'chefsidarbudak': 'food',
#  'sultangurmemeze': 'food',
#  'sortiesortie': 'fashion',
#  'besiktasjksporokullari': 'sports',
#  'welderwatch': 'fashion',
#  'davincicerrahi': 'health and lifestyle',
#  'drzekeriya.cetinkaya': 'health and lifestyle',
#  'verarestaurant': 'food',
#  'cafedeparissuadiye': 'food',
#  'fx57': 'tech',
#  'zigananisantasi': 'food',
#  'temiz_hava_hakki': 'health and lifestyle',
#  'ezhersolmazz': 'entertainment',
#  'keyfiviranebeylikduzu': 'entertainment',
#  'guroymakbelediyesi': 'travel',
#  'cfmototurkiye': 'sports',
#  'ismailssay': 'mom and children',
#  'germiyanbilgekoleji': 'mom and children',
#  'darulacezebaskanligi': 'mom and children',
#  'bkmsahne': 'entertainment',
#  'littleonesflorya': 'mom and children',
#  'danonekidstr': 'food',
#  'okuvaryum': 'mom and children',
#  'goreme_cappadocia': 'travel',
#  'katinamezeevi': 'food',
#  'ofeliabeykent': 'food',
#  'turkiyeihracatcilarmeclisi': 'tech',
#  'ekicipeynir': 'food',
#  'turlasanacom': 'travel',
#  'ckenerji': 'tech',
#  'expo2016antalya': 'mom and children',
#  'hdiskender1995': 'food',
#  'metekayagil': 'entertainment',
#  'umrantoo': 'mom and children',
#  'ihkibirlik': 'fashion',
#  'tamek': 'food',
#  'nebimyazilim': 'tech',
#  'orkidturkiye': 'sports',
#  'sural_hotels': 'travel',
#  'ugurbilgin': 'entertainment',
#  'kacuv': 'mom and children',
#  'demirdokumtr': 'tech',
#  'etimek': 'food',
#  'viteltr': 'tech',
#  'ulkerbiskrem': 'food',
#  'agitoyazilim': 'tech',
#  'besiktas': 'sports',
#  'spitalispecialbahceci': 'health and lifestyle',
#  'cizzbizzalsancak': 'food',
#  'yakasidusler': 'entertainment',
#  'sevibebe': 'mom and children',
#  'pegasosclub': 'travel',
#  'istanbulhealthsave': 'health and lifestyle',
#  'makbulkurumsal': 'food',
#  'kubrakoccc_': 'fashion',
#  'cemilteris': 'food',
#  'woodyturkiye': 'fashion',
#  'adkickboxing': 'sports',
#  'cemens_mutfak': 'food',
#  'kralsakir': 'entertainment',
#  'fun21turkiye': 'entertainment',
#  'littlekitchenofficial': 'food',
#  'icindekiyemekaski': 'food',
#  'baskayol': 'travel',
#  '45lik.alsancak': 'entertainment',
#  'drzerclinic': 'health and lifestyle',
#  'paydaplatformu': 'mom and children',
#  'yeryuzudoktorlari': 'health and lifestyle',
#  'maslakaparts': 'travel',
#  'haresurel': 'art',
#  'serangocer': 'health and lifestyle',
#  'kocaeliannesehir': 'mom and children',
#  'ortheroaligner': 'health and lifestyle',
#  'elmarkplus': 'tech',
#  'istanbulcazfestivali': 'entertainment',
#  'biyosnet': 'tech',
#  'justeatuk': 'food',
#  'murat_bostanci': 'sports',
#  'etkineczacilikdernegi': 'health and lifestyle',
#  'kasapdursun': 'food',
#  'crmturizm': 'travel',
#  'yali_spor': 'fashion',
#  'gorunmezkaza': 'fashion',
#  'freshopcomtr': 'food',
#  'bepremiumbodrum': 'travel',
#  'ihhinsaniyardim': 'mom and children',
#  'dedikodubjk': 'sports',
#  'ealltun': 'travel',
#  'cengizunder': 'sports',
#  'tokatseyahat060': 'travel',
#  'kitesandmiles': 'entertainment',
#  'gmarinakemer': 'travel',
#  'mirror_restaurant': 'food',
#  'ayvalikfeneryolubalikcisi': 'food',
#  'orucogluyaglari': 'food',
#  'metamazon_tr': 'health and lifestyle',
#  'captainergun': 'travel',
#  'konyagram': 'travel',
#  'pernigottiturkiye': 'food',
#  'pasajcookbook': 'food',
#  'bahttiyatro': 'entertainment',
#  'yuvaclub': 'food',
#  'psikiyatristibrahimbilgen': 'health and lifestyle',
#  'aspendossuites': 'travel',
#  'arkapizzeria': 'food',
#  'dogostore': 'fashion',
#  'nimsfoodglobal': 'food',
#  'etipronot': 'food',
#  'eczhalilsahin07': 'mom and children',
#  'trparkinsonhastaligidernegi': 'health and lifestyle',
#  'tugbayurt': 'entertainment',
#  'drmehmetcerci': 'mom and children',
#  'bolezpilic': 'food',
#  'hillsidebeachclub': 'travel',
#  'turkcellesk': 'tech',
#  'koffcoffeecompany': 'food',
#  'merzaesthetics': 'health and lifestyle',
#  'chouettelle': 'fashion',
#  'metinhara': 'health and lifestyle',
#  'drozanseymen': 'health and lifestyle',
#  'simatarkan': 'fashion',
#  'galerist': 'art',
#  'sokeninlezzetleri': 'food',
#  'heymamastyle': 'mom and children',
#  'orjinaltur': 'travel',
#  'memetsimsek': 'art',
#  'marlinecafebistro': 'food',
#  'teknosa': 'tech',
#  'elvankreatif': 'fashion',
#  'elazig_mem': 'mom and children',
#  'etenfes': 'food',
#  'abdulkadirsahinerr': 'mom and children',
#  'malatyapazaripalanci': 'food',
#  'hisfederasyonu': 'health and lifestyle',
#  'marsalatextile': 'fashion',
#  'ayipubmoda': 'fashion',
#  'pringles_turkiye': 'food',
#  'lotusbakeriesturkiye': 'food',
#  'okuzburger_tr': 'food',
#  'kod8net': 'tech',
#  'tatilbudurcom': 'travel',
#  'bodrumfoods': 'food',
#  'zuhaldentakilar': 'fashion',
#  'alpay.var': 'mom and children',
#  'tetrabilisim': 'tech',
#  'kelloggsturkiye': 'food',
#  'seastarbutik_bungalovotel': 'travel',
#  'qaburgaet': 'food',
#  'gamesmedya': 'art',
#  'bayenkatechnology': 'tech',
#  'mks_kilit_sistemleri': 'tech',
#  'dtiimplantsystems': 'tech',
#  'nisanurkayseri': 'fashion',
#  'ozsubalik': 'food',
#  'orman_lezzetleri': 'food',
#  'fourbeachclub_': 'travel',
#  'umitaktasofficial': 'health and lifestyle',
#  'sokaksuavi': 'food',
#  'neva_kadikoy': 'food',
#  'yuttyfamily': 'food',
#  'merihdemiral': 'sports',
#  'mavirotatour': 'travel',
#  'tzatzikimeyhane': 'mom and children',
#  'lezzet_dergisi': 'food',
#  'rokabahce': 'food',
#  'rixospera': 'travel',
#  'yagizizgul': 'food',
#  'mandarin_mango_hotel': 'travel',
#  'nilufer_turizm': 'travel',
#  'griffart': 'fashion',
#  'breathhub_tr': 'health and lifestyle',
#  'sumigurumi': 'mom and children',
#  'balikada_izmir': 'food',
#  'durdenmodumuz': 'sports',
#  'burulasulasim': 'travel',
#  'kanyon_da': 'entertainment',
#  'haydevira': 'sports',
#  'golf.roko': 'entertainment',
#  'pastasusumuzz_06': 'food',
#  'italturloves': 'travel',
#  'taburemizah': 'food',
#  'fanticmotorturkiye': 'sports',
#  'superslowzonedenizli': 'health and lifestyle',
#  'kigiligiyim': 'fashion',
#  'veyselkaptantour': 'travel',
#  'asicstr': 'fashion',
#  'anthavenbodrum': 'travel',
#  'yeni.lokanta': 'food',
#  'loncagirisim': 'tech',
#  'corendonairlines': 'travel',
#  'seckinsteak': 'food',
#  'gomapizza03': 'food',
#  'nefesimyeter': 'health and lifestyle',
#  'eleganestetik': 'health and lifestyle',
#  ...}

# %%
len(username_category)
# Out:
# 2890

# %%
train_classification.groupby('label').count()
# Out:
#                       username
# label
# art                        191
# entertainment              323
# fashion                    299
# food                       511
# gaming                      13
# health and lifestyle       503
# mom and children           149
# sports                     113
# tech                       346
# travel                     294

# %%
import json
import pandas as pd

train_data_path = "training-dataset.jsonl"

username_post_train = {}
username_profile_train = {}
username_biography_train = {}

username_post_test = {}
username_profile_test = {}
username_biography_test = {}

username_follower_count = {}  # Mapping of username -> follower_count

with open(train_data_path, "r", encoding="utf-8") as fh:
    for line in fh:
        sample = json.loads(line.strip())
        profile = sample["profile"]

        username = profile["username"]
        follower_count = profile.get("follower_count", 0)  # Follower count (default is 0 if missing)
        biography = profile.get("biography", "")           # Biography (default is "" if missing)

        # Separate into training or test sets based on the availability of category information
        if username in username_category:
            # Training
            username_post_train[username] = sample["posts"]
            username_profile_train[username] = profile
            username_biography_train[username] = biography
        else:
            # Test
            username_post_test[username] = sample["posts"]
            username_profile_test[username] = profile
            username_biography_test[username] = biography

        # Save follower count
        username_follower_count[username] = follower_count

# Convert profile information to a DataFrame
# `reset_index(drop=True)` creates a new integer index starting from zero.
train_profile_df = pd.DataFrame(username_profile_train).T.reset_index(drop=True)
test_profile_df  = pd.DataFrame(username_profile_test).T.reset_index(drop=True)

# Display the first 5 rows as an example
print(train_profile_df.head(5))
# Out:
#                username           id                     full_name  \
# 0            deparmedya   3170700063                   Depar Medya
# 1            kafesfirin    266439571                   KAFES FIRIN
# 2              vimerang   2367195567                      Vimerang
# 3  yusufelibelediyesi08  43824173432  Yusufeli Belediye Başkanlığı
# 4     mustafa_yalcinn38   9606564254               Mustafa Yalçın
#
#                                            biography   category_name  \
# 0           #mediaplanning #mediabuying #sosyalmedya  Local business
# 1  📍Söğütözü📍FTZ AVM\n🛒Ankara macro▲center v...           Brand
# 2       Dijital İletişim Yönetimi🎬info@vimerang.comq            None
# 3  Yusufeli Belediye Başkanlığı Resmi İnstagram H...       Community
# 4                            Talas Belediye Başkanı      Politician
#
#   post_count follower_count following_count is_business_account is_private  \
# 0       None           1167             192                True      False
# 1       None          11997              17                True      False
# 2       None           2321             454                True      False
# 3       None           4635              83                True      False
# 4       None          13647              29                True      False
#
#    ...  business_category_name overall_category_name  category_enum  \
# 0  ...                    None                  None          LOCAL
# 1  ...                    None                  None          BRAND
# 2  ...  Creators & Celebrities                  None  VIDEO_CREATOR
# 3  ...                    None                  None           None
# 4  ...                    None                  None     POLITICIAN
#
#   is_verified_by_mv4b is_regulated_c18  \
# 0               False            False
# 1               False            False
# 2               False            False
# 3               False            False
# 4               False            False
#
#                                      profile_pic_url should_show_category  \
# 0  https://instagram.fsaw2-3.fna.fbcdn.net/v/t51....                 True
# 1  https://instagram.fada1-13.fna.fbcdn.net/v/t51...                 True
# 2  https://instagram.fist19-1.fna.fbcdn.net/v/t51...                 True
# 3  https://instagram.fszf2-1.fna.fbcdn.net/v/t51....                False
# 4  https://instagram.fist1-4.fna.fbcdn.net/v/t51....                 True
#
#   should_show_public_contacts show_account_transparency_details  \
# 0                        True                              True
# 1                        True                              True
# 2                        True                              True
# 3                       False                              True
# 4                       False                              True
#
#                               profile_picture_base64
# 0  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
# [5 rows x 44 columns]

# %%
train_profile = pd.DataFrame(username_profile_train).T.reset_index(drop=True)
test_profile = pd.DataFrame(username_profile_test).T.reset_index(drop=True)

train_profile.head(5)
# Out:
#                username           id                     full_name  \
# 0            deparmedya   3170700063                   Depar Medya
# 1            kafesfirin    266439571                   KAFES FIRIN
# 2              vimerang   2367195567                      Vimerang
# 3  yusufelibelediyesi08  43824173432  Yusufeli Belediye Başkanlığı
# 4     mustafa_yalcinn38   9606564254               Mustafa Yalçın
#
#                                            biography   category_name  \
# 0           #mediaplanning #mediabuying #sosyalmedya  Local business
# 1  📍Söğütözü📍FTZ AVM\n🛒Ankara macro▲center v...           Brand
# 2       Dijital İletişim Yönetimi🎬info@vimerang.comq            None
# 3  Yusufeli Belediye Başkanlığı Resmi İnstagram H...       Community
# 4                            Talas Belediye Başkanı      Politician
#
#   post_count follower_count following_count is_business_account is_private  \
# 0       None           1167             192                True      False
# 1       None          11997              17                True      False
# 2       None           2321             454                True      False
# 3       None           4635              83                True      False
# 4       None          13647              29                True      False
#
#    ...  business_category_name overall_category_name  category_enum  \
# 0  ...                    None                  None          LOCAL
# 1  ...                    None                  None          BRAND
# 2  ...  Creators & Celebrities                  None  VIDEO_CREATOR
# 3  ...                    None                  None           None
# 4  ...                    None                  None     POLITICIAN
#
#   is_verified_by_mv4b is_regulated_c18  \
# 0               False            False
# 1               False            False
# 2               False            False
# 3               False            False
# 4               False            False
#
#                                      profile_pic_url should_show_category  \
# 0  https://instagram.fsaw2-3.fna.fbcdn.net/v/t51....                 True
# 1  https://instagram.fada1-13.fna.fbcdn.net/v/t51...                 True
# 2  https://instagram.fist19-1.fna.fbcdn.net/v/t51...                 True
# 3  https://instagram.fszf2-1.fna.fbcdn.net/v/t51....                False
# 4  https://instagram.fist1-4.fna.fbcdn.net/v/t51....                 True
#
#   should_show_public_contacts show_account_transparency_details  \
# 0                        True                              True
# 1                        True                              True
# 2                        True                              True
# 3                       False                              True
# 4                       False                              True
#
#                               profile_picture_base64
# 0  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
# [5 rows x 44 columns]

# %%
test_profile.head(5)
# Out:
#                      username          id                      full_name  \
# 0              beyazyakaliyiz  8634457436             Selam Beyaz Yakalı
# 1  totalenergies_istasyonlari  7066643793    TotalEnergies İstasyonları
# 2                 konforyatak  8782109673  Konfor Yatak #KonforluUykular
# 3                    ht_kulup  1950140344                       HT KULÜP
# 4                   ajansspor   338611487                      Ajansspor
#
#                                            biography         category_name  \
# 0        Beyaz yakalıların dünyasına hoşgeldiniz 😀😀😀         Personal blog
# 1  TotalEnergies İstasyonları resmi Instagram hes...        Energy Company
# 2  Konfor Yatak, birbirinden farklı özelliklere s...             Furniture
# 3                    Bloomberght - Habertürk Magazin                  None
# 4  🏢 Saran Group \n🏟 Anında, tarafsız spor haberl...  News & media website
#
#   post_count follower_count following_count is_business_account is_private  \
# 0       None           1265             665                True      False
# 1       None          28025               4                True      False
# 2       None          40334               2                True      False
# 3       None         158877              69                True      False
# 4       None          93193             286                True      False
#
#    ... business_category_name overall_category_name   category_enum  \
# 0  ...                   None                  None   PERSONAL_BLOG
# 1  ...                   None                  None  ENERGY_COMPANY
# 2  ...                   None                  None       FURNITURE
# 3  ...                   None                  None         TV_SHOW
# 4  ...                   None                  None       NEWS_SITE
#
#   is_verified_by_mv4b is_regulated_c18  \
# 0               False            False
# 1               False            False
# 2               False            False
# 3               False            False
# 4               False            False
#
#                                      profile_pic_url should_show_category  \
# 0  https://instagram.fist6-1.fna.fbcdn.net/v/t51....                 True
# 1  https://instagram.fsaw2-1.fna.fbcdn.net/v/t51....                 True
# 2  https://instagram.fyei6-3.fna.fbcdn.net/v/t51....                 True
# 3  https://instagram.fada2-1.fna.fbcdn.net/v/t51....                 True
# 4  https://instagram.fadb2-1.fna.fbcdn.net/v/t51....                 True
#
#   should_show_public_contacts show_account_transparency_details  \
# 0                        True                              True
# 1                        True                              True
# 2                        True                              True
# 3                        True                              True
# 4                        True                              True
#
#                               profile_picture_base64
# 0  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
#
# [5 rows x 44 columns]

# %%
print(len(train_profile), len(test_profile))
# Out:
# 2815 2600

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
import re


def preprocessing_text(text):
    # If text is None, assign an empty string
    if text is None:
        text = ""
    
    # Convert text to lowercase
    text = text.casefold()
    # Remove URLs
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    # Remove non-alphanumeric characters except hashtags and mentions
    text = re.sub(r'[^a-zçğıöşü0-9\s#@]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text


corpus = []  # List to hold processed text data
training_usernames = []  # List to hold usernames

for username, post in username_post_train.items():
    training_usernames.append(username)

    # Clean the captions
    cleaned_captions = []
    for p in post:
        post_caption = p.get('caption', '')
        if post_caption is None:
            continue

        post_caption = preprocessing_text(post_caption)
        if post_caption != '':
            cleaned_captions.append(post_caption)

    # Clean and add the biography
    biography = username_biography_train.get(username, '')
    cleaned_biography = preprocessing_text(biography)

    # Combine captions and biography
    user_text = "\n".join(cleaned_captions + [cleaned_biography])
    corpus.append(user_text)


# TF-IDF Vectorization
vectorizer = TfidfVectorizer(stop_words=combined_stopwords, max_features=7500)

vectorizer.fit(corpus)

x_post_train = vectorizer.transform(corpus)
y_train = [username_category[username] for username in training_usernames]

feature_names = vectorizer.get_feature_names_out()

# Convert the TF-IDF matrix to a DataFrame
tfidf = pd.DataFrame(
    x_post_train.toarray(), 
    columns=feature_names, 
    index=username_post_train.keys()
)

# Remove a specific column ("bir") from the DataFrame
filtered_version = tfidf.drop("bir", axis=1)

# ---------------------------
# 3) Adding profile information and categories
# ---------------------------
# Profile information of all users
train_profile = pd.DataFrame(username_profile_train).T

# Extract category_name information
train_profile['category_name'] = train_profile['category_name'].str.split().str[0]
train_profile["category_name"] = train_profile["category_name"].fillna("unknown")  # Fill missing categories

# One-hot encode the categories
encoder = OneHotEncoder()
category_features = encoder.fit_transform(train_profile["category_name"].values.reshape(-1, 1))

# Convert one-hot encoded results to a DataFrame
category_features_df = pd.DataFrame(
    category_features.toarray(),
    columns=encoder.get_feature_names_out(["category_name"]),
    index=train_profile.index
)

# Combine `filtered_version` with category features
combined_features = pd.concat([filtered_version, category_features_df], axis=1)

# ---------------------------
# 4) TF-IDF vectorization for the test set (Caption + Biography)
# ---------------------------
test_corpus = []  # List to hold processed text data for test set
test_usernames = []  # List to hold test usernames

for username, post in username_post_test.items():
    test_usernames.append(username)

    # Clean the captions
    cleaned_captions = []
    for p in post:
        post_caption = p.get('caption', '')
        if post_caption is None:
            continue

        post_caption = preprocessing_text(post_caption)
        if post_caption != '':
            cleaned_captions.append(post_caption)

    # Clean and add the biography
    biography = username_biography_test.get(username, '')
    if biography is None:
        biography = ''
        
    cleaned_biography = preprocessing_text(biography)

    # Combine captions and biography
    user_text = "\n".join(cleaned_captions + [cleaned_biography])
    test_corpus.append(user_text)

x_post_test = vectorizer.transform(test_corpus)

# Convert the test TF-IDF matrix to a DataFrame
test_tfidf = pd.DataFrame(
    x_post_test.toarray(), 
    columns=feature_names, 
    index=username_post_test.keys()
)

# %%
assert y_train.count("NA") == 0

# %%
if "bir" in filtered_version.columns:
    print("True")
else:
    print("False")
# Out:
# False

# %%
filtered_version.shape
# Out:
# (2815, 7499)

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report
from collections import Counter
import re
import nltk
from nltk.corpus import stopwords

# Download stopwords and combine them
nltk.download('stopwords')
turkish_stopwords = stopwords.words('turkish')
english_stopwords = stopwords.words('english')
combined_stopwords = list(set(turkish_stopwords + english_stopwords))

# Text preprocessing function
def preprocessing_text(text):
    if text is None:
        text = ""
    text = text.casefold()
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    text = re.sub(r'[^a-zçğıöşü0-9\s#@]', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

# Create the caption corpus
def build_caption_corpus(username_post):
    caption_corpus = []
    usernames = []

    for username, posts in username_post.items():
        usernames.append(username)
        cleaned_captions = [
            preprocessing_text(post.get('caption', ''))
            for post in posts if post.get('caption', '')
        ]
        user_text = "\n".join(cleaned_captions)
        caption_corpus.append(user_text)
    return caption_corpus, usernames

# Create the biography corpus
def build_biography_corpus(username_biography):
    biography_corpus = []
    usernames = []

    for username, biography in username_biography.items():
        usernames.append(username)
        cleaned_biography = preprocessing_text(biography)
        biography_corpus.append(cleaned_biography)
    return biography_corpus, usernames

# Create separate Caption and Biography corpora
caption_corpus, caption_usernames = build_caption_corpus(username_post_train)
biography_corpus, biography_usernames = build_biography_corpus(username_biography_train)

# Define and train separate TF-IDF vectorizers
caption_vectorizer = TfidfVectorizer(stop_words=combined_stopwords, max_features=7500)
biography_vectorizer = TfidfVectorizer(stop_words=combined_stopwords, max_features=2500)

# Fit and transform the data
x_caption_train = caption_vectorizer.fit_transform(caption_corpus)
x_biography_train = biography_vectorizer.fit_transform(biography_corpus)

# Retrieve feature names
caption_feature_names = caption_vectorizer.get_feature_names_out()
biography_feature_names = biography_vectorizer.get_feature_names_out()

# Convert the TF-IDF matrices to DataFrames
caption_tfidf = pd.DataFrame(
    x_caption_train.toarray(),
    columns=caption_feature_names,
    index=caption_usernames
)

biography_tfidf = pd.DataFrame(
    x_biography_train.toarray(),
    columns=biography_feature_names,
    index=biography_usernames
)

# Combine TF-IDF matrices
combined_tfidf = pd.concat([caption_tfidf, biography_tfidf], axis=1).fillna(0)

# Combine profile information and categories
train_profile = pd.DataFrame(username_profile_train).T
train_profile['category_name'] = train_profile['category_name'].str.split().str[0]
train_profile['category_name'] = train_profile['category_name'].fillna('unknown')

# One-hot encode the categories
encoder = OneHotEncoder()
category_features = encoder.fit_transform(train_profile['category_name'].values.reshape(-1, 1))
category_features_df = pd.DataFrame(
    category_features.toarray(),
    columns=encoder.get_feature_names_out(['category_name']),
    index=train_profile.index
)

# Combine TF-IDF and category features
combined_features = pd.concat([combined_tfidf, category_features_df], axis=1).fillna(0)

# Check and clean class distribution
valid_usernames = [username for username in username_category.keys() if username in combined_features.index]
filtered_combined_features = combined_features.loc[valid_usernames]
filtered_y_train = [username_category[username] for username in valid_usernames]

class_counts = Counter(filtered_y_train)
filtered_data = [(x, y) for x, y in zip(filtered_combined_features.index, filtered_y_train) if class_counts[y] > 1]
filtered_combined_features = filtered_combined_features.loc[[x for x, y in filtered_data]]
filtered_y_train = [y for x, y in filtered_data]

# Split the data into training and validation sets
x_train, x_val, y_train, y_val = train_test_split(
    filtered_combined_features,
    filtered_y_train,
    test_size=0.2,
    stratify=filtered_y_train
)

# Train and evaluate the Naive Bayes model
model = MultinomialNB()
model.fit(x_train, y_train)

# Evaluate performance
y_train_pred = model.predict(x_train)
print("Train Accuracy:", accuracy_score(y_train, y_train_pred))
print("Train Classification Report:\n", classification_report(y_train, y_train_pred, zero_division=0))

y_val_pred = model.predict(x_val)
print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))
print("Validation Classification Report:\n", classification_report(y_val, y_val_pred, zero_division=0))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ganga\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Train Accuracy: 0.7800977343402932
# Train Classification Report:
#                        precision    recall  f1-score   support
#
#                  art       0.97      0.38      0.55       157
#        entertainment       0.66      0.75      0.70       265
#              fashion       0.86      0.83      0.84       244
#                 food       0.88      0.96      0.92       414
#               gaming       0.00      0.00      0.00        14
# health and lifestyle       0.62      0.91      0.74       413
#     mom and children       0.97      0.23      0.37       121
#               sports       0.98      0.50      0.66       100
#                 tech       0.83      0.91      0.87       287
#               travel       0.89      0.76      0.82       236
#
#             accuracy                           0.78      2251
#            macro avg       0.77      0.62      0.65      2251
#         weighted avg       0.81      0.78      0.76      2251
#
# Validation Accuracy: 0.6252220248667851
# Validation Classification Report:
#                        precision    recall  f1-score   support
#
#                  art       0.57      0.10      0.17        40
#        entertainment       0.36      0.36      0.36        66
#              fashion       0.70      0.72      0.71        61
#                 food       0.75      0.88      0.81       104
#               gaming       0.00      0.00      0.00         3
# health and lifestyle       0.52      0.75      0.61       103
#     mom and children       0.75      0.10      0.18        30
#               sports       1.00      0.36      0.53        25
#                 tech       0.63      0.83      0.72        72
#               travel       0.83      0.66      0.74        59
#
#             accuracy                           0.63       563
#            macro avg       0.61      0.48      0.48       563
#         weighted avg       0.64      0.63      0.60       563

# %%
test_data_path = "test-classification-round3.dat"

test_unames = []
with open(test_data_path, "rt") as fh:
  for line in fh:
    test_unames.append(line.strip())

print(test_unames[:5])
# Out:
# ['schirogomme', 'takviyegiller', 'egeasalmetal_', 'expomedeurasia', 'izmirhim']

# %%
x_test = []

for uname in test_unames:
  try:
    index = test_usernames.index(uname)
    x_test.append(x_post_test[index].toarray()[0])
  except Exception as e:
    try:
      index = training_usernames.index(uname)
      x_test.append(x_post_train[index].toarray()[0])
    except Exception as e:
      print(uname)

# remove screenname
#test_unames.remove("screenname")

# %%
len(x_test)
# Out:
# 1000

# %%
len(test_unames)
# Out:
# 1000

# %%
import numpy as np

# List of all features used in training
training_feature_names = combined_features.columns

# Convert test data to a DataFrame
df_test = pd.DataFrame(np.array(x_test), columns=feature_names)
df_test.head(2)

# Add missing columns and fill with 0
for col in training_feature_names:
    if col not in df_test.columns:
        df_test[col] = 0

# Arrange columns in the same order
df_test = df_test[training_feature_names]

# Make predictions
test_pred = model.predict(df_test)

# Generate output
output = dict()
for index, uname in enumerate(test_unames):  # Replace test_unames with test_usernames
    output[uname] = test_pred[index]

# Check the output
print(output)
# Out:
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# ...
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# C:\Users\ganga\AppData\Local\Temp\ipykernel_14796\1641931476.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_test[col] = 0
# {'schirogomme': 'tech', 'takviyegiller': 'health and lifestyle', 'egeasalmetal_': 'tech', 'expomedeurasia': 'tech', 'izmirhim': 'health and lifestyle', 'hotelveneraistanbul': 'travel', 'thepearlofgreece': 'fashion', 'ferrerorocherturkiye': 'food', 'meyhanedeyiz.biz': 'food', 'ozatashipyard': 'tech', 'cartmancase': 'tech', 'thermexturkiye': 'tech', 'kedi7_com': 'food', 'frostoys': 'mom and children', 'kayagrubu': 'tech', 'tavukdunyasikariyer': 'health and lifestyle', 'sukrugencbaskan': 'health and lifestyle', 'oguzhankapilar': 'entertainment', 'yrefahesenyurt': 'health and lifestyle', 'dedemanpalandokenskilodge': 'travel', 'fideyoapp': 'entertainment', 'fiatkastamonugozde': 'tech', 'nakisgidaofficial': 'health and lifestyle', 'instakocaali': 'travel', 'refahist': 'health and lifestyle', 'umutayildiz': 'health and lifestyle', 'kadikoybelediye': 'health and lifestyle', 'fanatikcomtr': 'sports', 'ecift': 'entertainment', 'kumsalistanbul': 'food', 'wenotrat': 'entertainment', 'alaralokum': 'food', 'firatgunayer': 'entertainment', 'quagranite': 'tech', 'gamzeozcelikk': 'health and lifestyle', 'diyetisyengamzealtinay': 'food', 'bilgekeykubat': 'food', 'kozagourmet': 'food', 'mustafasandal24': 'entertainment', 'tiyatrokalandar': 'entertainment', 'tonniestyres': 'fashion', 'pendikbolgehastanesi': 'health and lifestyle', 'sertranssocial': 'tech', 'alemdarinsaatbolu': 'tech', 'nazimzekiuysal': 'entertainment', 'newyorkburgerizmir': 'food', 'enginaricilik.tr': 'food', 'kentparkavm': 'entertainment', 'zenpirlanta': 'fashion', 'scandiborn': 'fashion', 'aycasenbaskan': 'entertainment', 'yoncasahinbas': 'health and lifestyle', 'bysaygi': 'fashion', 'mediviasaglikgrubu': 'health and lifestyle', 'lensmarket_com': 'tech', 'tuimagiclife_masmavi': 'travel', 'kbbmustafaak': 'health and lifestyle', 'herseyyanimda': 'fashion', 'kursunlubeltr': 'health and lifestyle', 'melkeontheroad': 'travel', 'tui_blue_seno': 'travel', 'lollibonicandytoys': 'tech', 'ekrempirlanta': 'fashion', 'minisoturkey': 'fashion', 'fdnsirketlergrubu': 'health and lifestyle', 'barcintancan': 'health and lifestyle', 'badmintonfederasyonu': 'health and lifestyle', 'babapizzacesme': 'food', 'turktelekombasketbol': 'health and lifestyle', 'gsb_kirikkale': 'health and lifestyle', 'gemliklife': 'health and lifestyle', 'sehirtiyatrosu': 'entertainment', 'livingroomist': 'entertainment', 'gulen.gunduz.yilmaz': 'health and lifestyle', 'sansursuzproff': 'food', 'stonebarizmir': 'food', 'kartepebelediyesi': 'health and lifestyle', 'flutv.online': 'entertainment', 'ahmetturgayoguz': 'health and lifestyle', 'tadalezzetleri': 'food', 'mapeiturkiye': 'tech', 'kizilgunmelodi': 'travel', 'evdekolay': 'food', 'stanley_turkiye': 'food', 'jciistanbul': 'health and lifestyle', 'risendanismanlik': 'tech', 'ozelkonakhastanesi': 'health and lifestyle', 'ushanckr': 'entertainment', 'mekandanbolnevar': 'food', 'korayaydintr': 'health and lifestyle', 'safran_group': 'fashion', 'sigortamjet': 'health and lifestyle', 'solargezi': 'health and lifestyle', 'aslitandoga': 'entertainment', 'expertyol': 'tech', 'muratbur': 'health and lifestyle', 'fikriuludag52': 'health and lifestyle', 'tiyatrolar': 'entertainment', 'sfrpztf': 'entertainment', 'ikbalthermal': 'travel', 'chp': 'health and lifestyle', 'biraltmislik': 'entertainment', 'technical_sharing': 'fashion', 'superfitshoes_turkey': 'health and lifestyle', 'cocuklargulsundiye': 'health and lifestyle', 'boytekstekstil': 'travel', 'thecraton.hotel': 'travel', 'samsunetkinlik': 'entertainment', 'uztex1943': 'fashion', 'pepsiturkiye': 'food', 'sintanchemicals': 'fashion', 'ekremyavas.10': 'health and lifestyle', 'twitchdenkesitler': 'health and lifestyle', 'kadikoylibertabar': 'food', 'mutfaktayusufvar': 'food', 'cilemakar': 'entertainment', 'ezgi_basaran': 'travel', 'denizbaysal_': 'entertainment', 'jessicamayofficial': 'entertainment', 'ilkaysencan': 'travel', 'reklamcikafasi': 'food', 'primeveterinaryhospital': 'health and lifestyle', 'mekemrobot': 'tech', ' ...

# %%
len(df_test)
# Out:
# 1000

# %%
# Filter columns that start with 'category_name'
category_columns = df_test.columns[df_test.columns.str.startswith('category_name')]

# Find columns with values different from 0
non_zero_columns = category_columns[df_test[category_columns].ne(0).any()].tolist()

# Print the result
print(non_zero_columns)
# Out:
# []

# %%
df_test.columns
category_columns = []
for col in df_test.columns:
    if col.startswith('category_name'):
        category_columns.append(col)

category_columns
# Out:
# ['category_name_Actor',
#  'category_name_Advertising',
#  'category_name_Advertising/Marketing',
#  'category_name_Aerospace',
#  'category_name_Agricultural',
#  'category_name_Agriculture',
#  'category_name_Animal',
#  'category_name_Apartment',
#  'category_name_App',
#  'category_name_Aquarium',
#  'category_name_Architectural',
#  'category_name_Art',
#  'category_name_Artist',
#  'category_name_Arts',
#  'category_name_Athlete',
#  'category_name_Author',
#  'category_name_Automation',
#  'category_name_Automotive',
#  'category_name_Aviation',
#  'category_name_Baby',
#  'category_name_Bags/Luggage',
#  'category_name_Bakery',
#  'category_name_Bar',
#  'category_name_Beach',
#  'category_name_Beauty',
#  'category_name_Beauty,',
#  'category_name_Bicycle',
#  'category_name_Biotechnology',
#  'category_name_Blinds',
#  'category_name_Blogger',
#  'category_name_Boat',
#  'category_name_Book',
#  'category_name_Bookstore',
#  'category_name_Brand',
#  'category_name_Bridal',
#  'category_name_Broadcasting',
#  'category_name_Building',
#  'category_name_Burger',
#  'category_name_Bus',
#  'category_name_Business',
#  'category_name_Butcher',
#  'category_name_Cafe',
#  'category_name_Campus',
#  'category_name_Canal',
#  'category_name_Car',
#  'category_name_Cargo',
#  'category_name_Carpet',
#  'category_name_Cars',
#  'category_name_Caterer',
#  'category_name_Charity',
#  'category_name_Cheese',
#  'category_name_Chef',
#  'category_name_Chemical',
#  'category_name_Child',
#  'category_name_Chocolate',
#  'category_name_City',
#  'category_name_Civilization',
#  'category_name_Clothing',
#  'category_name_Coach',
#  'category_name_Cocktail',
#  'category_name_Coffee',
#  'category_name_College',
#  'category_name_Comedian',
#  'category_name_Comfort',
#  'category_name_Comic',
#  'category_name_Commercial',
#  'category_name_Community',
#  'category_name_Company',
#  'category_name_Computer',
#  'category_name_Computers',
#  'category_name_Construction',
#  'category_name_Consulting',
#  'category_name_Cosmetic',
#  'category_name_Cosmetics',
#  'category_name_Dairy',
#  'category_name_Dance',
#  'category_name_Defense',
#  'category_name_Deli',
#  'category_name_Dentist',
#  'category_name_Design',
#  'category_name_Designer',
#  'category_name_Dessert',
#  'category_name_Digital',
#  'category_name_Doctor',
#  'category_name_Donut',
#  'category_name_E-commerce',
#  'category_name_Editor',
#  'category_name_Education',
#  'category_name_Educational',
#  'category_name_Electric',
#  'category_name_Electronics',
#  'category_name_Elevator',
#  'category_name_Energy',
#  'category_name_Engineering',
#  'category_name_Entrepreneur',
#  'category_name_Esports',
#  'category_name_Event',
#  'category_name_Family',
#  'category_name_Fashion',
#  'category_name_Fast',
#  'category_name_Festival',
#  'category_name_Film',
#  'category_name_Finance',
#  'category_name_Financial',
#  'category_name_Fishing',
#  'category_name_Florist',
#  'category_name_Food',
#  'category_name_Footwear',
#  'category_name_Franchise',
#  'category_name_Furniture',
#  'category_name_Games/toys',
#  'category_name_Gaming',
#  'category_name_Gastropub',
#  'category_name_General',
#  'category_name_Gift',
#  'category_name_Government',
#  'category_name_Graphic',
#  'category_name_Grocery',
#  'category_name_Gym/Physical',
#  'category_name_Hair',
#  'category_name_Harbor',
#  'category_name_Health',
#  'category_name_Health/beauty',
#  'category_name_Heating,',
#  'category_name_History',
#  'category_name_Home',
#  'category_name_Hospital',
#  'category_name_Hospitality',
#  'category_name_Hotel',
#  'category_name_Household',
#  'category_name_Ice',
#  'category_name_Industrial',
#  'category_name_Information',
#  'category_name_Insurance',
#  'category_name_Interest',
#  'category_name_Internet',
#  'category_name_Internist',
#  'category_name_Italian',
#  'category_name_Japanese',
#  'category_name_Jewelry',
#  'category_name_Jewelry/watches',
#  'category_name_Journalist',
#  'category_name_Just',
#  'category_name_Kitchen/cooking',
#  'category_name_Landscape',
#  'category_name_Lighting',
#  'category_name_Live',
#  'category_name_Local',
#  'category_name_Lounge',
#  'category_name_Machine',
#  'category_name_Magazine',
#  'category_name_Makeup',
#  'category_name_Marina',
#  'category_name_Marketing',
#  'category_name_Media',
#  'category_name_Media/news',
#  'category_name_Medical',
#  'category_name_Mediterranean',
#  'category_name_Meeting',
#  'category_name_Model',
#  'category_name_Motor',
#  'category_name_Motorcycle',
#  'category_name_Movie',
#  'category_name_Museum',
#  'category_name_Music',
#  'category_name_Musician',
#  'category_name_Musician/band',
#  'category_name_National',
#  'category_name_Neurologist',
#  'category_name_News',
#  'category_name_Non-Governmental',
#  'category_name_Nonprofit',
#  'category_name_Nurseries',
#  'category_name_Nutritionist',
#  'category_name_Obstetrician-Gynecologist',
#  'category_name_Organization',
#  'category_name_Otolaryngologist',
#  'category_name_Outdoor',
#  'category_name_Performance',
#  'category_name_Performing',
#  'category_name_Personal',
#  'category_name_Pet',
#  'category_name_Pharmaceutical',
#  'category_name_Pharmaceuticals',
#  'category_name_Phone/Tablet',
#  'category_name_Photographer',
#  'category_name_Photography',
#  'category_name_Physical',
#  'category_name_Pilates',
#  'category_name_Plastic',
#  'category_name_Political',
#  'category_name_Politician',
#  'category_name_Portable',
#  'category_name_Preschool',
#  'category_name_Printing',
#  'category_name_Private',
#  'category_name_Producer',
#  'category_name_Product/service',
#  'category_name_Professional',
#  'category_name_Prosthodontist',
#  'category_name_Psychologist',
#  'category_name_Pub',
#  'category_name_Public',
#  'category_name_Publisher',
#  'category_name_RV',
#  'category_name_Radio',
#  'category_name_Real',
#  'category_name_Recycling',
#  'category_name_Residence',
#  'category_name_Restaurant',
#  'category_name_Retail',
#  'category_name_School',
#  'category_name_Science',
#  'category_name_Science,',
#  'category_name_Scientist',
#  'category_name_Screen',
#  'category_name_Seafood',
#  'category_name_Shopping',
#  'category_name_Show',
#  'category_name_Ski',
#  'category_name_Skin',
#  'category_name_Social',
#  'category_name_Society',
#  'category_name_Software',
#  'category_name_Solar',
#  'category_name_Soup',
#  'category_name_Spa',
#  'category_name_Specialty',
#  'category_name_Sports',
#  'category_name_Steakhouse',
#  'category_name_Sunglasses',
#  'category_name_Surfing',
#  'category_name_Surgical',
#  'category_name_TV',
#  'category_name_Talent',
#  'category_name_Tattoo',
#  'category_name_Telecommunication',
#  'category_name_Textile',
#  'category_name_Theatrical',
#  'category_name_Theme',
#  'category_name_Therapist',
#  'category_name_Tire',
#  'category_name_Tour',
#  'category_name_Tourist',
#  'category_name_Toy',
#  'category_name_Transit',
#  'category_name_Transportation',
#  'category_name_Travel',
#  'category_name_Turkish',
#  'category_name_Urologist',
#  'category_name_Used',
#  'category_name_Vegetarian/Vegan',
#  'category_name_Video',
#  'category_name_Village',
#  'category_name_Visual',
#  'category_name_Vitamins/supplements',
#  'category_name_Web',
#  'category_name_Website',
#  'category_name_Websites',
#  'category_name_Wedding',
#  'category_name_Wholesale',
#  'category_name_Writer',
#  'category_name_Youth',
#  'category_name_unknown']

# %%
normalized_table
# Out:
# {'mom and children': 'Mom and Children',
#  'food': 'Food',
#  'travel': 'Travel',
#  'fashion': 'Fashion',
#  'gaming': 'Gaming',
#  'health and lifestyle': 'Health and Lifestyle',
#  'entertainment': 'Entertainment',
#  'tech': 'Tech',
#  'sports': 'Sports',
#  'art': 'Art'}

# %%
test_pred = model.predict(df_test)

output_normalized = dict()

for index, uname in enumerate(test_unames):
    predicted_label = test_pred[index].strip().lower()  # Convert the predicted category to lowercase
    normalized_label = normalized_table.get(predicted_label, predicted_label.title())  # Normalize or default to title case
    output_normalized[uname] = normalized_label

# %%
len(test_pred)
# Out:
# 1000

# %%
with open("prediction-classification-round3.json", "w") as of:
  json.dump(output_normalized, of, indent=4)

# %%
# check for data inbalance
train_classification.groupby('label').count()
# Out:
#                       username
# label
# art                        191
# entertainment              323
# fashion                    299
# food                       511
# gaming                      13
# health and lifestyle       503
# mom and children           149
# sports                     113
# tech                       346
# travel                     294

# %%
test_usernames
# Out:
# ['beyazyakaliyiz',
#  'totalenergies_istasyonlari',
#  'konforyatak',
#  'ht_kulup',
#  'ajansspor',
#  '4bros.tr',
#  'drtubagunebak',
#  'nihatcan11',
#  'mustafaaakcay',
#  'mtmofamily',
#  'bonitoperde',
#  'balkanlardangelenlezzet',
#  'pedagoganne__gulozturk',
#  'iktm34',
#  'yudumyag',
#  'bulentozdemir.edebiyat',
#  'imtolstoyevski',
#  'yorkkadikoy',
#  'akkaalinda',
#  'mutfaktayusufvar',
#  'antmodern',
#  'immergasturkiye',
#  'vanillaantalya',
#  'ermanyasar',
#  'tuna.food',
#  'rustik.rus.restorani',
#  'ilhansen',
#  'institutfrancaisdeturquie',
#  'beachandbeyondswimwear',
#  'monsternotebook',
#  'bsynctr',
#  'kbbzone',
#  'dbbanyo',
#  'istanbulalpplastik',
#  'enka_insaat_official',
#  'ozyufka.com_tr',
#  'nationalturk',
#  'sametkaankuyucu',
#  'tutbelediyesi',
#  'odurla',
#  'balagency',
#  'sokebelediyesi',
#  'dedemanpalandokenskilodge',
#  'binefismutfak',
#  'tatli.sanati',
#  'evimin.yemekleri',
#  'ceyo_turkiye',
#  'berlinplatzpub.kadikoy',
#  'rotaradar',
#  'luppotr',
#  'bogaziciyoneticilervakfi',
#  'sestri.lifestyle',
#  'sarduvantiyatrosu',
#  'sevinckoleji',
#  'buddhasahne',
#  'billge',
#  'qualitasspalevent',
#  'ankarapodium',
#  'kahveborsam',
#  'booksandcoffeeturkiye',
#  'esila_kids',
#  'suphiaksoyb',
#  '01burdaavm',
#  'scstil.kampanya',
#  'thermomixtr',
#  'genpaonline',
#  'instamugla',
#  'sarigolbelediyesi',
#  '365avm',
#  'turktelekombasketbol',
#  'empatikcom',
#  'maysanmando',
#  'atopiokulu',
#  'fitajans',
#  'radikarestaurant',
#  'cornettotr',
#  'erciyasholding',
#  'monna.cafe',
#  'aykutyilmaz13',
#  'cetinkayapano',
#  'bagatellebodrum',
#  'fikirmod',
#  'hayratislamicgift',
#  'efeuygac',
#  'reeder.tr',
#  'mylittleponytr',
#  'rotekstekstil',
#  'orfionoliveoil',
#  'tc_giresunvaliligi',
#  'gsbasketbol',
#  'tosyaliholding',
#  'rey_hanem',
#  'erdqtr',
#  'ceyhunhamid',
#  'kanaldinternational',
#  'netelsan',
#  'fixpacktr',
#  'itef_istanbul',
#  'ajanslephaa',
#  'drdmotorbikes',
#  'hatice0ncel',
#  'beyoglubld',
#  'mehmetturgut',
#  'bekardgida',
#  'tiyatrosalt',
#  'baskanhulyaerdem',
#  'swipeline_tr',
#  'konyafarukgulluoglu',
#  'medipolsaglik',
#  'aliyagciii',
#  'erginnursel',
#  'gelinlikcilercarsisi',
#  'masalgercektiyatro',
#  'zamanekahvesi',
#  'pierrecardinhali',
#  'virahabercom',
#  'mtahmazoglu',
#  'erkanperdecom',
#  'kombicicevdet',
#  'neadelektrik',
#  'hasandogantr',
#  'minisoturkey',
#  'dedemanistanbul',
#  'medipointtipmerkezi',
#  'denizcanaktasofficial',
#  'dgym',
#  'guneyolimpikgsk',
#  'yaaydayiz',
#  'sabahaterdogans',
#  'gloriahotels',
#  'ozguryiilmaz',
#  'yemekcom',
#  'sigortamjet',
#  'gezsenisparta',
#  'gulkebap1949',
#  'gurmerehber',
#  'kocamaar',
#  'karincaproduksiyon',
#  'hyundai.cihangrup',
#  'caglametguler',
#  'oztayteksofficial',
#  'juniortedibear',
#  'abdiibrahimkariyer',
#  'drvolkandede',
#  'egeasalmetal_',
#  'taksimcamiivakfi',
#  'sandykedikumu',
#  'bafetto',
#  'sariyerbelediye',
#  'hayalkoseoglu',
#  'modaalamagaza',
#  'minik_o',
#  'adiyamanvalilik',
#  'alacatigardends',
#  'akgolcuk41',
#  'celsuskitabevi',
#  'shahulean',
#  'akdenizbld',
#  'kasperskytr',
#  'historiaavm',
#  'ilkayala',
#  'regenesismax',
#  'gulcanarslann',
#  'pwnistanbul',
#  'sigmacenter',
#  'kesandocek',
#  'sevi_travel',
#  'galvinnisantasi',
#  'furkanncagman',
#  'oxemarineturkiye',
#  'kepanaokulu',
#  'mesuterginofficial',
#  'naturelkapowders',
#  'tetrapak_tr',
#  'schirogomme',
#  'avmpomelon',
#  'digiboardtr',
#  'ozdilekboluavm',
#  'ekoorganik',
#  'zamanebaba',
#  'ebrar.can',
#  'serdarkilic_',
#  'edergiapp',
#  'akilliphone',
#  'cartmancase',
#  'rixospremiumtekirova',
#  'demiroren.holding',
#  'pinaraltug_atacan',
#  'assu_water',
#  'majalisfestival',
#  'digitalagencynetwork',
#  'sirenebelekhotel',
#  'piculetstore',
#  'withcoworking',
#  'aleynasolakerr',
#  'tiyatrokooperatifi',
#  'nevzatozkur0',
#  'sahanepazar',
#  'sozcumuratoglu',
#  'yapiturkeybuild',
#  'form_sirketler_grubu',
#  'bkbasketbol',
#  'dr_farukozlu',
#  'clipperturkey',
#  'avsibelsoylemez',
#  'fusetea_tr',
#  'buklatur',
#  'kirpikids',
#  'm.kemalsakaroglu',
#  'guncesanattiyatrosu',
#  'voguerestaurantistanbul',
#  'pinarlayasam',
#  'nevzatdindar',
#  'selenesn',
#  'kesifgezgini',
#  'siemprediamond',
#  'kaanurgancioglu',
#  'iremcalhan',
#  'suslebabyparty',
#  'mesdokum',
#  'crafttiyatro',
#  'turtletinyhouse',
#  'tozluyakafox_',
#  'hisarsofrasanati',
#  'horoz_aydinlatma',
#  'aslioymen',
#  'neff_el',
#  'tcvanvaliligi',
#  'anneler_kulubu',
#  'nisantasiuroloji',
#  'ozaysendir',
#  'zerrintekindor',
#  'araka.istanbul',
#  'tansudayan',
#  'cagdasonurozturk',
#  'suleymanaksoy.sa',
#  'komterateknoloji',
#  'keremalisik',
#  'grange.kadikoy',
#  'denizcengizz',
#  'tiretayfurcicek',
#  'francofontanajewelry',
#  'mozaikfolkdanstoplulugu',
#  'pertekbelediyesi',
#  'nilayerdonmez',
#  'caddekultursanat',
#  'ptdynamic',
#  'kalealarm',
#  'aykaya.ambalaj',
#  'gilletteturkiye',
#  'alarkocarrier',
#  'erimtanmuseum',
#  'betulynpzr',
#  'calgontr',
#  'sirtakiofficial',
#  'burgerillas',
#  'gsb_kirikkale',
#  'jalpersanofficial',
#  'rafadantayfa',
#  'mirdellav',
#  'aleynabesirm',
#  'meliketatar',
#  'dilart.design',
#  'gulizarbicer',
#  'yilgencitr',
#  'yilmazreduktor',
#  'yemektekeyifvar',
#  'hacibeyogullari',
#  'filtresizcom',
#  'dukasim.com.tr',
#  'wezzomart.tr',
#  'marulkafa',
#  'arkas_spor',
#  'diybagturkey',
#  'base.ist',
#  'montel.official',
#  'gdzeyas',
#  'prof.dr.a.bulentoktay',
#  'aycaucer',
#  'didemsoydan',
#  'neredeyemekyeriz',
#  'm1konyaavm',
#  'mikailcakmak.artstudio',
#  'bysaygi',
#  'sifir.atik',
#  'botas_spor',
#  'assoszeytinhanhotel',
#  'dsmartdunyasi',
#  'milliebobbybrown',
#  'azadylmaz',
#  'kadikoyemek',
#  'bebekhotelbythestay',
#  'kasaba.tv',
#  'baselifeclub',
#  'drbrownsturkey',
#  'soguktankorkma',
#  'defneilgaz.com.tr',
#  'cantenkaya',
#  'otsorganik',
#  'modafen',
#  'denizlibbld',
#  'trafikkonya',
#  'tcailesosyal',
#  'eskiyatv',
#  'etidanismanlik',
#  'genkord',
#  'turkiyeyedeger',
#  'iddaa',
#  'kucukciftlikpark',
#  'castaluxury',
#  'akyurtsupermarket',
#  'orvitalorganik',
#  'kivircik_collection',
#  'aysatiyatro',
#  'lezzetinadresicom',
#  'izbbkultursanat',
#  'arkasdeniztarihimerkezi',
#  'baleaprints',
#  'tonniestyres',
#  'beylikovabelediyesi',
#  'nilgunakbulut_',
#  'selcinn',
#  'anneveserra',
#  'ecovero.turkey',
#  'theboviera',
#  'setup34digital',
#  'umuteker',
#  'bmdonline',
#  'bakkalcioglu11',
#  'elvanreklamtr',
#  'assanpanel',
#  'whatupmell',
#  'aspendosdispoliklinigi',
#  'kirencekaya_balikcisi',
#  'sofosistanbul',
#  'marka.333',
#  'senpilic',
#  'sanatdan_',
#  'oyuncusendika',
#  'gencoozak',
#  'cetincivata',
#  'nestlecareerstr',
#  '1983beyoglu',
#  'jkrbar',
#  'monochrometr',
#  'drbetulsayan',
#  'elifcanongurlar',
#  'spicehotelbelek',
#  'kadinkoalisyonu',
#  'asortiemobilya',
#  'dipdisco',
#  'iremhlvcioglu',
#  'gulercetingoz',
#  'samsunayvacikbelediyesi',
#  'ferideozdincc',
#  'rockpub_moda',
#  'osmangazibld',
#  'winblocktr',
#  'amazon.tr',
#  'jmsuluslararasitasimacilik',
#  'kazanci.market',
#  'fanatikcomtr',
#  'rizebelediyesi',
#  'hepsen_2020',
#  'drumranileri',
#  'bebedorturkey',
#  'dilekcesur_',
#  'bodrumpark',
#  'kemerixofficial',
#  'novaarsaofficial',
#  'birddetective',
#  'sharkuterimedya',
#  'naturbes',
#  'ozelidayaslibakimmerkezi',
#  'silaaturkoglu',
#  'hardwareeurasia',
#  'gercekgundemcom',
#  'gezinoks',
#  'etimutlukutu',
#  'birfilolsaydim',
#  'acelyatopaloglu',
#  'motodociaofficial',
#  'miazzacoffee',
#  'marinturkavm',
#  'andacyesilyurt',
#  'kartepebelediyesi',
#  'moxxhouse',
#  'karincalogistics',
#  'pelinyarr',
#  'nexuskuafor',
#  'safeparkbeytepe',
#  'petsitterturkey',
#  'hisliseyler',
#  'lebleukusadasi',
#  'emniyetgm',
#  'begocan',
#  'fahrigediz',
#  'ecevahapoglu',
#  'mehmetcikvakfi',
#  'sergenozn',
#  'istguven_as',
#  'atolyekafasi',
#  'dyt.omercanyorulmaz',
#  'mesut_sure',
#  'selinayalcn',
#  'battalilgezdi34',
#  'burak.th',
#  'atasehirbld',
#  'denizzbolisik',
#  'kelepirsisli',
#  'biteatral',
#  'gurme_avukat',
#  'ilkerbekler60',
#  'acemdenizyel',
#  'orhangazibelediyesi',
#  'dr.estethica',
#  'highwayoutlet',
#  'theofficialprabh',
#  'hotelsidestarresort',
#  'igorturkiye',
#  'gayretmakina',
#  'mesutscl',
#  'karasugold',
#  'burakbulutfotografatolyesi',
#  'sarikizmadensuyu',
#  'antaresavm',
#  'theirishpub_caddebostan',
#  'gamerarena_com',
#  'ninovaparkavm',
#  'asyaalizaude',
#  'lezizsofralar',
#  'kardemirkarabukspor',
#  'canikkultur',
#  'acunilicali',
#  'oguzelibld27',
#  'tkdkagri',
#  'sanayi1a',
#  'hakansuer41',
#  'deutz_fahr_turkey',
#  'persanhomestudio',
#  'yasinkartoglu',
#  'ekulak',
#  'cebogluinsaat',
#  'beiniztv',
#  'rasimacarmhp',
#  'dilanamcalar',
#  'swipeline',
#  'halkapinarbelediyesi',
#  'salihkececi',
#  'ontangrup',
#  'isaleticom',
#  'yildizgaz',
#  'officialemirberkezincidi',
#  'istanbulbbsk',
#  'rotasizseyyah',
#  'turkuazoptik',
#  'atakuleofficial',
#  'arkasturizm',
#  'kosekahve',
#  'vaziyetcomtr',
#  'turkelibelediyesi',
#  'gandasart',
#  'korayaydintr',
#  'maison_turkey',
#  'holisticsanitas_official',
#  'nuumu',
#  'mustafa_col_',
#  'noluyoyaofficial',
#  'gencallar',
#  'gsb_erzincan',
#  'nafiz.solak',
#  'biosizmir',
#  'profdrilkersolmaz',
#  'lavarlaa',
#  'mustafakayalar76',
#  'sivaszaraavsar',
#  'sixttr',
#  'burcukoksal03',
#  'yasemoz88',
#  'zekeriyayapicioglu',
#  'uzerinebirseyler',
#  'pureencapsulations_tr',
#  'movcreative.tr',
#  'peakfitnessadana',
#  'pinarbasibeltr',
#  'melikeozdal',
#  'isiloguzz',
#  'ahlatbld',
#  'cemuzan',
#  'deselektrik',
#  'hindiba_dogaevi',
#  'kofteciramiz',
#  'izmiretkinlikleri',
#  'pekcetintemizlik',
#  'saffet_sancakli',
#  'bruderturkiye',
#  'borusansanat',
#  'gdz_edas',
#  'uysallarsunideri',
#  'trendyolhizlimarket',
#  'gokhangonul',
#  'serminyasarofficial',
#  'sncoilturkiye',
#  'erzurum.carsi.pazar',
#  'kirintirestaurant',
#  'argoalsancak',
#  'safran_group',
#  'madameamourdesign',
#  'dyo',
#  'zaferconcept',
#  '140journos',
#  'arifsevimli',
#  'lionelhotelistanbul',
#  'avlu34avm',
#  'bepantholbabyturkiye',
#  'refahist',
#  'fellahoglukuyumculukcepshop',
#  'iccesmemarina',
#  'ilginbld',
#  'hedefbeytotel',
#  'novikovbodrum',
#  'adasteccorp',
#  'karataybelediyesi',
#  'karnavalcom',
#  'zodyakli',
#  'bozcaadabld',
#  'kdzereglitso',
#  'brandingturkiye',
#  'hitsoft',
#  'numanoffice',
#  'puzzledepo',
#  'cizmecikedi',
#  '_mehmetbuse',
#  'barankusss',
#  'sherwoodresorts',
#  'pttcell_tr',
#  'isikmobilyatr',
#  'derelibel',
#  'officialturkishmuseums',
#  'koalareklam',
#  'oguzozyaral',
#  'genveonilac',
#  'lcwaikikikariyer',
#  'datcabelediyesi',
#  'fikirdelisi',
#  'donercialiusta',
#  'pinarfish',
#  'turkishaerospace',
#  'upl.turkey',
#  'scalamice',
#  'maltepehastanesi',
#  'gain',
#  'boncukyilmaz',
#  'ankaradakesif',
#  'izocamofficial',
#  'acmagile',
#  'primemallantakya',
#  'q_grafik',
#  'brandweekistanbul',
#  'alavyahotel',
#  'ihsanakmurat',
#  'hataysandikici',
#  'yapikredibomontiada',
#  'bungalovoteller',
#  'hayatikonusalim',
#  'sekakagitmuzesi',
#  'tevadimadim',
#  'gulgrupgayrimenkul',
#  'milangaz',
#  'psikezone',
#  'izmitbelediyespor',
#  'ksvvakfi',
#  'podyumsanatmahal',
#  'deltaparkavm',
#  'altayoguz1905',
#  'expertyol',
#  'dr.kubilayyucel',
#  'superfm',
#  'epiastr',
#  'yarplus',
#  'yegezokuyaz',
#  'ibfk2014',
#  'turkiyekickboksfederasyonu',
#  'medovahastanesi',
#  'didisogukcay',
#  'agromeyseafood',
#  'osesonadoyumolmaz',
#  'tellekt',
#  'celebizadeonline',
#  'richhousebistro',
#  'gizemkaraca',
#  'isleyen_moda.offical',
#  'biriciksuden',
#  'ozgebezirci',
#  'byelergumus',
#  'ilsanise',
#  'iksv_istanbul',
#  'magnumenerji',
#  'gzt',
#  'debboyakademi',
#  'axisistanbulavm',
#  'krdsturkiyeburanebeklion',
#  'eseryenenler',
#  'bjkkadinfutbol',
#  'bekiraksun',
#  'beb_turkey',
#  'vividenttr',
#  'yigitpoyrazz',
#  'boztaspremium',
#  'bancocomtr',
#  'ecebelenn',
#  'aysenilsamlioglu',
#  'berkriptepe',
#  'oxabrasive',
#  'cheetosturkiye',
#  'merterenbulbul1',
#  'derentalu',
#  'ipekkyazici',
#  'granadaluxury',
#  'kaymoskayseri',
#  'aksehir.belediyesi',
#  'regispatent',
#  'mimarturgayerdem',
#  'bemuze.promosyon',
#  'termebelediyesi',
#  'magnumturkiye',
#  'ilyastopsakal',
#  'zadeyaglari',
#  'izmircocukcalismalariagi',
#  'asst76',
#  'hesabinibilenanne',
#  'klproturkiye',
#  'yoncaakova',
#  'burakaltindag',
#  'kadinlarfestivali',
#  'u_ibrahim_altay',
#  'ayseninbavulu',
#  'baruthotels',
#  'realworksglobal',
#  'kesifmekan',
#  'alinuraktas',
#  'logoyazilimkariyer',
#  'ferhatyilmaz66',
#  'brkhkmn',
#  'yilturturizm',
#  'girafestore',
#  'yuzyuzeykens',
#  'onvoelektronik',
#  'ozelalgomedhastanesi',
#  'exxen',
#  'beylikduzubelediye',
#  'juice_planet',
#  'aysebrav',
#  'lcwdream',
#  'beka_beka_anaokulu',
#  'scandiborn',
#  'psikolog.arslan',
#  'sedabakan',
#  'muglabsb',
#  'nihalcandanbeauty',
#  'artonistanbul',
#  'fmcturkey',
#  'turkish_stones',
#  'agacin.izinde',
#  'rehberle',
#  'trgyguler',
#  'arslangurerr',
#  'ckoncagul',
#  'undanoekmek',
#  'kahvaltidunyasi.tullumi',
#  'antmarealacati',
#  'alakargayayinlari',
#  'jackandjones_tr',
#  'mertgungory',
#  'halil.ibrahim.senol',
#  'medyagurme',
#  'finikebelediye',
#  'kalamis.cundali',
#  'idil.duru.cinar',
#  'gsb_bartin',
#  'mplusturkiye',
#  'ferrerorocherturkiye',
#  'restoranmodern_',
#  'ckalebelediye',
#  'itublockchain',
#  'esmergil',
#  'ucgenpigment',
#  'pelincutakyan',
#  'drselcukyuce',
#  'sertranssocial',
#  'marksandspencerturkiye',
#  'barcintancan',
#  'trabzondatiyatro',
#  'prof.dr.halilalis',
#  'fuatsarigul',
#  'thecitysuitestr',
#  'bayburtbelediyesi_',
#  'anemonankaraotel',
#  'kendinemuzisyen',
#  'gemliklife',
#  'helloheallthy',
#  'kirecburnu',
#  'nilaybale',
#  'lechicbodrum',
#  'caddetipmerkezi',
#  'erkem.et',
#  'cansudere',
#  '3d_maket',
#  'seyirdernegi',
#  'veli.gok32',
#  'ceturturkiye',
#  'sarkoybelediyesi',
#  'ezgi_basaran',
#  'recepaktimur',
#  'sportsdigitale',
#  'ahmetarasbodrum',
#  'babilkulesi_',
#  '_seymaunal_',
#  'bestoss',
#  'sansursuzproff',
#  'bmcsavunma',
#  'imvu',
#  'odyomedbursa',
#  'drkenansahin',
#  'hataybsb',
#  'sevenseashotelblue',
#  'ergunmakinahirdavat',
#  'yamanerkuyumculuk',
#  'ahmethamdigork',
#  'tusasshop',
#  'kuzucu_mucevherat',
#  'alperenbabacan',
#  'biostoretr',
#  'impladent',
#  'bisalt',
#  'gsb_kayseri',
#  'buyukorhanbelediyesi',
#  'kalp.360',
#  'protekvip',
#  'alpolic.com.tr',
#  'aksipub',
#  'kentonturkiye',
#  'begendikmagaza',
#  'fundaery',
#  'tugcemelisdemir',
#  'rawsomebar',
#  'brewgorillas',
#  'arsuzhaber',
#  'kormetaljant',
#  'kasrezervasyon',
#  'diyeting',
#  'pelinsutilki',
#  'kamilsaracoglu43',
#  'farkyaratanlarsabancivakfi',
#  'empastorecom',
#  'makromet.metallurgy',
#  'tezatsanat',
#  'merrellturkiye',
#  'keciorenbelediyesi06',
#  'takieftalya',
#  'elibollardanbusraaa',
#  'gaziantepanadoluspor',
#  'ozerpan',
#  'ahbap',
#  'ozdilekusakavm',
#  'atikailesi',
#  'okanerertugrul',
#  'medyaiyifikir',
#  'oralbtr',
#  'btginsaat',
#  'umit.cetinkayaa',
#  'songullka',
#  'bensusoral',
#  'arasedas',
#  'cukurovabasketbol',
#  'sayginbaykaracom',
#  'deryacobanofficial',
#  'safa__sari',
#  'alpatayazilim',
#  'exitedu',
#  'albondaluminium',
#  'pasifikeurasia',
#  'samsunsehirgazetesi',
#  'huseyinoprukcu',
#  'olurbutik',
#  'kadinicinteknoloji',
#  'pelinkarahan',
#  'grandyaziciclubturban',
#  'kisabiralinti',
#  'ogretmeninkaleminden_',
#  'gurbetinmutfagi',
#  'thelifecoshop',
#  'octopodart',
#  'hestourex',
#  'malatyakultursosyal',
#  'khgmimarlik',
#  '_ismailbulbul_',
#  'promosyonshow',
#  'meyhanedeyiz.biz',
#  'oioibebekleri',
#  'dentaloji',
#  'worldfoodistanbul',
#  'c.kalehalkkutuphanesi',
#  'guralpremier',
#  'mostphotos',
#  'yagmurkrbll',
#  'dremrehocaoglu',
#  'diyetiko_',
#  'drberikademir',
#  'gomecbelediyesi',
#  'merwishop',
#  'idillfirat',
#  'uzaypastanesi',
#  'aperinastudios',
#  'maltepebeltr',
#  'thermapadofficial',
#  'zynp_odnc',
#  'umitkantarcilar',
#  'eforosgb',
#  'arzuakbaszor',
#  'aksankozmetik',
#  'ayfabasin',
#  'niyazigunesmobilya',
#  'refikabirgul',
#  'afmeinsaat',
#  'read_think_twice',
#  'gurpinarbel',
#  'aydintepebeltr',
#  'semaozpekmezci',
#  'kocakjewelry',
#  'yusuferdogan032',
#  'aquayasamofficial',
#  'gulseli.com.tr',
#  'bridgerestaurant',
#  'sofitel',
#  'chocolademoda',
#  'tiyatromundus',
#  'tekincreativemedia',
#  'firattanis',
#  'mantragastropub',
#  'armailacsan',
#  'lastdoor_tr',
#  'noriyongida',
#  'monetthome',
#  'sosyaleczaci',
#  'birkansokullu1',
#  'tav_guvenlik',
#  'fnss_savunma',
#  'arminarmcoffeeandbar',
#  'metinfeyzioglu',
#  'cocobolinho',
#  'healthyfoodbreak',
#  'kozayarismasi',
#  'lenovamobilya',
#  'kayarentakaravan',
#  'everfastenings',
#  'babyoneturkiye',
#  'prontomice',
#  'kornisonajans',
#  '253binyasin',
#  'ilkaysencan',
#  'neslihanmentes_edibleart',
#  'sosyallig',
#  'gsb_adiyaman',
#  'fethikaraduman',
#  'debuttiyatro',
#  'punchkadikoy',
#  'aydinmustafa',
#  'womedeluxe',
#  'rosakadindernegi',
#  'milliyetcihareketpartisi',
#  'zepterinternational',
#  'yapimboyle',
#  'kayrasocial',
#  'kesfetmek_guzeldir',
#  'bebegiminmarketicom',
#  'mimarelifkose',
#  'fatmakakacoglu',
#  'labrandaephesusprincess',
#  'peri_hankoca',
#  'burger_yesek_duzce',
#  'villasunflowerhotel',
#  'studyoima',
#  'dr.nerminfilizcivarilsuha',
#  'kirklarelihaberi',
#  'cumbalimeyhane',
#  'talentglobalhr',
#  'idaorgonite',
#  'dentacturkiye',
#  'solargezi',
#  'doguscay',
#  'sedaakgul',
#  'omeryesilbas',
#  'serhanonat',
#  'findiklibel',
#  'thestayalacati',
#  'letsdoitturkey',
#  'vitalproteins_tr',
#  'alacabld',
#  'pak_metal',
#  'mamaspapas.tr',
#  'konseptkutucom',
#  'cemozkaynak',
#  'mdetcenter',
#  'fitnessmovementinstitute',
#  'rozetsepeti',
#  'nazimcerkes',
#  '42maslak',
#  'aysebilgeselcuk',
#  'candastolga',
#  'turkiyeatletizmvakfi',
#  'ekegizem',
#  'ajwasultanahmet',
#  'dipa.funclub',
#  'dogukan_kilic',
#  'artdehuile_',
#  'kirmiziocakbasi',
#  'adile_ozdag',
#  'onikisubatbeltr',
#  'mehmetsavran50',
#  'arifibrahimoff',
#  'playshow_night_club_istanbul',
#  'lezzetimutfak',
#  'imuneksfarma',
#  'armonipark',
#  'quagranite',
#  'glingerietr',
#  'cokguzelhareketler2',
#  'pusulabungalow',
#  'kadinsaglikkulubu',
#  'ozkanncom',
#  'digitalexsolutions',
#  'yigitcanic',
#  'mervetoy',
#  'waffleci',
#  'ciftelerbelediyesi',
#  'bebeto',
#  'akgunwalker',
#  'redkutu',
#  'sahinirmak',
#  'tkdkordu',
#  'yesim_aykin',
#  'aksuvital',
#  'trendoil.com.tr',
#  'futbolarena',
#  'sabancidemet',
#  'parla_design',
#  'sihirliyolculuk',
#  'selcukticodasi',
#  'alcheracom',
#  'atelye79_jewellery',
#  'selinkidil',
#  'kronotrop',
#  'tulinnalbayrak',
#  'ajansdipa',
#  'ozlemgezginn',
#  'adiyaman_park_avm',
#  'rizepazarbelediyesi',
#  'zeynephautecouture',
#  'ibbsporistanbul',
#  'arnavutkoybelediyesi',
#  'pasta34shop',
#  'tmuratkolbasi',
#  'primemall.gaziantep',
#  'vodafonetr',
#  'yapikredikultursanat',
#  'zul.ays',
#  'izmirkalkinma',
#  'pierrecardinwomen',
#  'seykocaluminyum',
#  'unlimited_rag',
#  'yasakelmafox',
#  'conceptbungalow',
#  'fittogodietitian',
#  'mustafasarigul_',
#  'gursmehmet',
#  'hamidyuzugullu',
#  'kadikoy_etkinlikleri',
#  'arzularkabakoybel',
#  'sultanlarligi',
#  'yildirimdanisman',
#  'diyanettv',
#  'atlasparkavmist',
#  '16roof',
#  'ozeltanyeri',
#  'tkdktokat',
#  'selcuksahinofficial',
#  'stonelinecollections',
#  'koyulhisarbelediyesi58',
#  'mercedesbenzhafifticariarac',
#  'senaalaylom',
#  'mekoglobal',
#  'avmorion',
#  'bereketmarketleri',
#  'akcakalebld',
#  'perakende_gunleri',
#  'kuakmer',
#  'roinmax',
#  'manolyaurkan',
#  'pinarerbas_',
#  ...]

# %%
# check for test prediction distribution
pd.Series(test_pred).value_counts()
# Out:
# health and lifestyle    351
# food                    174
# entertainment           146
# tech                    139
# travel                   92
# fashion                  85
# sports                    6
# art                       5
# mom and children          2
# Name: count, dtype: int64

# %% [markdown]
# ## Regression Part

# %%
##########################################################
# Like Count Prediction (Regression) Code Example (Post-2019)
##########################################################
import json
import numpy as np
from pprint import pprint
from collections import defaultdict
import os
from datetime import datetime

# (1) Log MSE Metric
def log_mse_like_counts_log10(y_true, y_pred):
    """
    Log Mean Squared Error is calculated as log10(like_count + 1).
    """
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    # log10(like_count + 1)
    log_y_true = np.log10(y_true + 1)
    log_y_pred = np.log10(y_pred + 1)

    squared_errors = (log_y_true - log_y_pred) ** 2
    return np.mean(squared_errors)

def compute_95_percentile_cutoff(values):
    """
    Returns the 95th percentile cutoff value from the values list.
    """
    if len(values) == 0:
        return None
    return np.percentile(values, 95)

# (2) predict_like_count() function
def predict_like_count(username, current_post=None):
    """
    Generates predictions by looking at the average like_count for each media_type.
    If current_post is provided, it is excluded from the average calculation.
    Additionally, like_count values above the 95th percentile are considered outliers and excluded from the average.
    """
    def get_avg_like_count_by_media_type(posts: list):
        """
        1) Collect all like_count values (excluding current_post),
           discard values above the 95th percentile (outliers).
        2) Group the remaining posts by media_type and calculate the average.
        """
        # 1) Collect all like_count values to find the outlier cutoff
        all_likes = []
        for p in posts:
            if current_post is not None and p["id"] == current_post["id"]:
                continue
            all_likes.append(p.get("like_count", 0) or 0)

        if len(all_likes) == 0:
            return {}

        cutoff_95 = compute_95_percentile_cutoff(all_likes)
        if cutoff_95 is None:
            cutoff_95 = 0

        # 2) media_type -> [like_count] (collect non-outliers)
        media_type_likes = defaultdict(list)
        for p in posts:
            if current_post is not None and p["id"] == current_post["id"]:
                continue

            like_count = p.get("like_count", 0) or 0
            media_type = p.get("media_type", "UNKNOWN")
            # Outlier check
            if like_count <= cutoff_95:
                media_type_likes[media_type].append(like_count)

        # 3) Calculate averages
        avg_likes_by_media_type = {}
        for mtype, likes in media_type_likes.items():
            if likes:
                avg_likes_by_media_type[mtype] = sum(likes) / len(likes)
            else:
                avg_likes_by_media_type[mtype] = 0.0

        return avg_likes_by_media_type

    # If the user has data in train/test dict...
    if username in username_post_train:
        avg_likes = get_avg_like_count_by_media_type(username_post_train[username])
    elif username in username_post_test:
        avg_likes = get_avg_like_count_by_media_type(username_post_test[username])
    else:
        # Predict 0 if there is no data
        return 0

    # If current_post exists and media_type is known, return the average for that media_type
    if current_post and current_post.get("media_type") in avg_likes:
        prediction = avg_likes[current_post["media_type"]]
    else:
        # If media_type is unknown or not available
        if avg_likes:
            prediction = sum(avg_likes.values()) / len(avg_likes)
        else:
            prediction = 0.0

    return max(0, prediction)  # Ensure non-negative predictions

##########################################################
# (3) Reading Train Data and Filling username_post_train / test
##########################################################
train_data_path = "training-dataset.jsonl"

username_post_train = {}
username_post_test  = {}

# Determinant cutoff: Skip posts before 2019-01-01
CUTOFF_DATE = datetime(2019, 1, 1, 0, 0, 0)

def parse_timestamp(ts_str):
    """
    Converts a '2023-10-31 15:31:12' format string into a datetime object.
    Returns None if the format is incorrect.
    """
    try:
        return datetime.strptime(ts_str, "%Y-%m-%d %H:%M:%S")
    except:
        return None

with open(train_data_path, "r", encoding="utf-8") as fh:
    for line in fh:
        sample = json.loads(line.strip())
        profile = sample["profile"]
        posts   = sample.get("posts", [])

        uname = profile["username"]

        # Is it train or test?
        if uname in username_category:
            if uname not in username_post_train:
                username_post_train[uname] = []
        else:
            if uname not in username_post_test:
                username_post_test[uname] = []

        # Filter posts by checking "timestamp"
        for p in posts:
            like_count = p.get("like_count", 0) or 0
            media_type = p.get("media_type", "UNKNOWN")
            post_id    = p.get("id", "noid")
            post_ts_str= p.get("timestamp", "")  # "2023-10-31 15:31:12"
            post_dt = parse_timestamp(post_ts_str)

            # Skip if timestamp cannot be parsed (None) or post_dt < CUTOFF_DATE
            if not post_dt or post_dt < CUTOFF_DATE:
                continue

            # Posts after 2019-01-01
            post_dict = {
                "id": post_id,
                "like_count": like_count,
                "media_type": media_type,
                "timestamp": post_ts_str
            }

            # Add to train or test
            if uname in username_category:
                username_post_train[uname].append(post_dict)
            else:
                username_post_test[uname].append(post_dict)

print("Number of users in train dataset (for like_count):", len(username_post_train))
print("Number of users in test dataset (for like_count):", len(username_post_test))

##########################################################
# (4) Train Dataset Evaluation
##########################################################
y_like_count_train_true = []
y_like_count_train_pred = []

for uname, posts in username_post_train.items():
    for post in posts:
        pred_val = predict_like_count(uname, current_post=post)
        true_val = post["like_count"]
        y_like_count_train_true.append(true_val)
        y_like_count_train_pred.append(pred_val)

train_log_mse = log_mse_like_counts_log10(y_like_count_train_true, y_like_count_train_pred)
print(f"[Train] log10 MSE = {train_log_mse:.4f}")

##########################################################
# (5) Generating and Saving Predictions on Test Data
##########################################################
test_regression_datapath = "test-regression-round3.jsonl"
output_path = "prediction-regression-round3.json"

output_dict = {}

with open(test_regression_datapath, "rt") as fh:
    for line in fh:
        sample = json.loads(line.strip())
        uname = sample["username"]

        # For predictions, pass the sample to 'current_post' parameter
        pred_val = predict_like_count(uname, current_post=sample)

        sample["like_count"] = int(pred_val)
        output_dict[sample["id"]] = sample["like_count"]

with open(output_path, "w", encoding="utf-8") as of:
    json.dump(output_dict, of, indent=4)

print(f"Predictions saved to '{output_path}'!")
# Out:
# {'caption': 'Nergiz 34 yaşında Özbekistan\n'
#             "6 yıldır Türkiye'de.\n"
#             '3 yıl villa ,temizlik yemek deneyimleri var. \n'
#             "Ümraniye'de oturuyor.\n"
#             'Ayakta anne yada temizlik işleri istiyor.\n'
#             'Oturum izni ve\xa0referansı\xa0var.\n'
#             '\n'
#             'Adayımızla ilgili bizimle iletişime geçebilirsiniz 😊🍀 \n'
#             '\n'
#             'Erenköy Danışmanlık \n'
#             '0216 363 13 73\n'
#             'www.erenkoydanismanlik.com \n'
#             '\n'
#             '#bakıcı #bakici #cocukbakicisi #özbekbakıcı #türkmenbakıcı '
#             '#filipinlibakıcı #afrikalıbakıcı #ingilizcebilenbakıcı '
#             '#danışmanlık #yaşlıbakıcısı #hastabakıcı #avrupabakıcı '
#             '#avrupahastabakici',
#  'comments_count': 0,
#  'id': '18115268470322981',
#  'media_type': 'IMAGE',
#  'media_url': 'https://scontent-sof1-1.cdninstagram.com/v/t51.29350-15/395473950_1063251994801508_7273187389115076453_n.jpg?_nc_cat=100&ccb=1-7&_nc_sid=c4dd86&_nc_ohc=fh3YxJxUBRAAX-edhND&_nc_oc=AQlgecleIKVPaaoQk0qwlw9COmUGAfkZiWr654Ke_p3KB3ly32V9dB-WlYWBmy4Out4&_nc_ht=scontent-sof1-1.cdninstagram.com&edm=AL-3X8kEAAAA&oh=00_AfBmVddZi06-SiiBOvMHtJAEnPV3sVfghcCmPdbuZuzq6A&oe=6559DCD2',
#  'timestamp': '2023-10-26 19:13:43',
#  'username': 'erenkoy_danismanlik'}
